# %% [markdown]
# **To make the assignment, first run the code below to import the right libraries.**

# %%
# =================================
# Imports
# =================================
from PyCh import *
from numpy import random
from dataclasses import dataclass
from matplotlib import pyplot
import math
# Out:
# PyCh version 2.1 imported succesfully.

# %% [markdown]
# <h1><center> 4DC10. Intermediate assignment</center></h1>
# <h2><center> Modeling and simulation of an autonomous vehicle storage and retrieval system</center></h2>
#
# # 1 Subject
#
# Today's competitive environment, in which deliveries need to be faster and order sizes become smaller, forces material handling providers to progressively develop new and better solutions. A recent development in automated material-handling technology for unit load storage and retrieval is the autonomous vehicle storage and retrieval system (AVS/RS). Figure 1 shows a representation of an AVS/RS for the handling of totes, while Figure 2 illustrates a single tier (floor, level). The storage racks are single-deep and double-sided. Each storage position is of the same size and can hold one tote. Lifts are mounted at fixed locations at one end of each storage aisle. The input/output (I/O) point is located at the first tier beside each lift. Autonomous vehicles are dedicated to a storage aisle within a specific tier (so-called tier-captive configuration). The first position on either side of the storage aisle in all tiers serves as a buffer and is used to manage the transfer of totes between vehicles and lifts (see Figure 2). One buffer (out) handles totes which have been retrieved, the other one (in), located on the other side of the storage aisle, handles the totes to be stored. The presence of these buffers allows the lift and vehicle to work independently of each other.
#
# The throughput performance of AVS/RS systems can be affected by design decisions (such as number of tiers, number of aisles, and depth of aisles) as well as operational decisions (such as tote storage location and order assignment).
#
# Figure 1: AVS/RS with tier-captive configuration [1] | Figure 2: Single tier in AVS/RS [1]
# - | -
# <img src="figures/avs.png" alt="drawing" width="400"/> | <img src="figures/avrs2.png" alt="drawing" width="400"/>

# %% [markdown]
# # 2 Goal
# The goal of this assignment is to study this new material handling solution by using computer simulation. This study can be restricted to the retrieval process only, i.e., the vehicles perform only single retrieval cycles. Clearly, the retrieval phase is the most critical activity from an organisational viewpoint, as it is directly related to customer service level and &mdash; in contrast to the storage phase &mdash; it cannot be postponed to a period of low workload.
#
# The objectives of this assignment can be summarized as follows:
# - Develop a simulation model of one aisle that consists of several tiers with retrieval process to assess the system performance in terms of throughput and flow time.
# - Systematically develop the model process by process, and verify and validate each process using analytical results.
# - Investigate design trade-offs, i.e., via different layouts (number of columns and tiers), for this material handling system.

# %% [markdown]
# # 3 Description of the AVS/RS
# The AVS/RS is a fully automated system that can store and retrieve unit loads. The unit loads are placed in totes, a type of box, and these totes are placed in a designated aisle and column for storage. When retrieved, an autonomous vehicle places the totes in a buffer at the end of the aisle. There is one autonomous vehicle for every aisle within the tier. This is called the tier-captive configuration. From the buffer, the totes are picked by a lift that serves all tiers in one aisle, see Figure 2. In this assignment only one aisle that consists of $Levels$ tiers has to be modelled. Each aisle has depth number of columns of width $dv$ metres and height $dl$ metres.
#
# Requests for a tote arrive for each tier, asking for a tote with a random (uniformly distributed) column assigned to it. The inter arrival time of requests is exponentially distributed with mean value $arrive$.
#
# The vehicles transport totes along the aisle (one vehicle per tier). The time taken by the vehicle to process an order depends on the tote's location. The vehicle has to travel to this location, load the tote (it takes a fixed amount of time equal to $lv$ seconds), then go back to the end of the aisle and, finally, unload the tote to the buffer (again this takes $lv$ seconds). The speed profile of each vehicle is described as follows. First, the vehicle goes with a constant acceleration $av$ *m/s$^2$* until it reaches its maximum velocity $vmaxv$, then it moves with this velocity and decelerates with a constant deceleration $av$ to approach its destination point. If the tote is located too close to the end of the aisle, it is possible that the vehicle will not reach its maximum speed.
#
# The vehicles unload the totes to a location where it is picked up by the lift. At any given time only one tote per tier is allowed to occupy such a position.
#
# The lift transports the totes from every tier to the ground floor. The processing time depends on the tote's location and the fixed time to load and unload the tote ($ll$ seconds for loading and $ll$ seconds for unloading). The maximum speed of the lift is $vmaxl$ $m/s$ with a speed profile similar to that of the vehicles (constant acceleration/deceleration of $al$ *m/s<sup>2</sup>*).

# %% [markdown]
# # 4 Modeling of the AVS/RS
# The model consists of several processes communicating via channels, see Figure 3.
#
# | Figure 3: The processes in the model |
# -
# <img src="figures/avrs.png" alt="drawing" width="400"/>
#
# A brief description of the processes is given below:
# - **G:** The generator models the arrival of orders for totes. There is one generator per tier.
# - **DB:** The demand buffer stores the orders to be picked up by the vehicles. The vehicle processes the orders under first-come-first-serve policy. It can always receive a tote, but it releases a tote only when the vehicle is ready to pick it up.
# - **V:** The vehicle can be modeled as a server with a variable processing time.
# - **GDV:** The process consisting of a Generator, Demand Buffer and Vehicle for one tier of the AVS/RS system.
# - **B:** The buffer stores the totes from the vehicles awaiting for a pick-up by the lift. The buffer operates under first-come-first-serve policy and has a finite capacity of $bc$ totes per tier. So, every tier has a buffer location of finite capacity of $bc$ totes. All those locations together form the buffer B that accommodates all the totes which are processed by the same lift. When the buffer is not empty (there is at least one tote on one of the tiers), the buffer sends information about the tier of the longest waiting tote to the lift upon request. This information is used by the lift to determine the location of the tote (the number of the tier the tote is located in). Once the lift is ready to pick it up, the tote is released to the lift. There are two types of queues in the buffer: $xs$ contains all the totes to be picked up by the lift and there are $Levels$ counters $n$ counting the totes from the corresponding tier.
# - **L:** The lift, similar to the process **V**, is modeled as a machine with a variable processing time. A lift first receives a destination tier. Then the process delays for time required for the lift to go to the tote location and pick up the tote. Then it receives the tote, and next it delays for the time required to go to the ground floor and to unload the tote. After that the lift process is ready to release the tote to the Exit process.
# - **E:** In the exit process all the data related to each tote are collected. This process calculates the average throughput and the average flow-time. The number of totes to be processed by the AVS/RS during one simulation run is determined by the constant $number\_of\_orders$.

# %% [markdown]
# # 5 Remark concerning report
# The assignment must be handed in two ways: a report in PDF with the answers to each question, as well as this jupyter notebook file. The report has to contain concise answers to the questions posed. Avoid unnecessary long explanations, however answers to analytical questions without an argument will result in no points. Include all important python code in your report, but only include code of the processes you have modified (e.g. the Generator process in Exercise 6.1.b). Failing to submit both the PDF and notebook files will result in a point reduction.
#
# Note that some of the simulations in the last few exercises can take some time to run, so plan accordingly.

# %% [markdown]
# # 6 Assignment
# When making a PyCh specification, one does not build an entire model and then starts debugging. A model is build step by step. During each step proper functionality is checked. We therefore model one process at a time, and connect the process with a Generator and/or Exit process to test proper functionality. In order to test proper functionality we first use analytical methods to determine the expected outcome. Then we run simulations to verify if these outcomes are indeed obtained. If that is the case, we can be more convinced that the process has been modeled correctly.

# %% [markdown]
# ## 6.1 Exercise 1: Generator (5 points)
# So the first step is to write a proper generator for a tier. To that end, the first model we build consists of (only) a Generator process and an Exit process collecting the totes generated by the Generator. The inter arrival time of requests is exponentially distributed with mean $arrive$. The requested tote should be retrieved from a random (uniformly distributed) column, where there are $depth$ columns in total (the columns ranging from 0 till 54).

# %% [markdown]
# a. Determine (analytically) the throughput and flow time that should result from your model with only the generator process and the exit process.

# %% [markdown]
# Answer: ...

# %% [markdown]
# b. Complete the Generator code in the template below. Confirm that your simulations produce the correct throughput and flow time, and that the minimal and maximal column returned by your simulation are respectively 0 and 54.

# %%
# =================================
# Tote
# =================================
@dataclass
class Tote:
    entrytime: float = 0.0
    column: int = 0

# =================================
# Generator
# =================================
@process
def Generator(env, c_out, arrive, depth):
    e = lambda: random.exponential(arrive)
    u = lambda: random.randint(0,depth) 
    while True:
        x = Tote(entrytime = env.now, column = u() )
        yield env.execute(c_out.send(x))
        delay = e()
        yield env.timeout(delay)


# =================================
# Exit
# =================================
@process
def Exit(env, c_in, number_of_orders):
    mphi = 0
    for i in range(1, number_of_orders + 1):
        x = yield env.execute(c_in.receive())
        mphi = (i - 1) / i * mphi + (env.now - x.entrytime) / i

        print(f"tote = {i:6d};"  
              f"  Entrytime = {x.entrytime: 10.4f};" 
              f"  Column = {x.column:2d};"
              f"  Mean throughput =" + (f"{i / env.now:8.6f}"   if   env.now   else f"{'N.A.':>8s}") +
              f"  Mean flowtime = {mphi:6.4f}"
        )


# =================================
# Model
# =================================
def model():
    # Variables
    arrive = 70.0             # inter arrival time of requests
    depth  = 55               # the number of columns
    
    number_of_orders = 100    # the number of orders to process        

    env = Environment()
    a = Channel(env)
    G = Generator(env, a, arrive, depth)
    E = Exit(env, a, number_of_orders)
    env.run(until=E)
    print ("simulation has ended")

# =================================
# Main
# =================================
model()
# Out:
# tote =      1;  Entrytime =     0.0000;  Column = 17;  Mean throughput =    N.A.  Mean flowtime = 0.0000
# tote =      2;  Entrytime =    36.1662;  Column = 10;  Mean throughput =0.055300  Mean flowtime = 0.0000
# tote =      3;  Entrytime =    81.9364;  Column = 44;  Mean throughput =0.036614  Mean flowtime = 0.0000
# tote =      4;  Entrytime =   280.4344;  Column = 39;  Mean throughput =0.014264  Mean flowtime = 0.0000
# tote =      5;  Entrytime =   293.6755;  Column = 12;  Mean throughput =0.017026  Mean flowtime = 0.0000
# tote =      6;  Entrytime =   417.6494;  Column = 32;  Mean throughput =0.014366  Mean flowtime = 0.0000
# tote =      7;  Entrytime =   427.9127;  Column = 48;  Mean throughput =0.016358  Mean flowtime = 0.0000
# tote =      8;  Entrytime =   463.4669;  Column = 54;  Mean throughput =0.017261  Mean flowtime = 0.0000
# tote =      9;  Entrytime =   470.8933;  Column =  9;  Mean throughput =0.019113  Mean flowtime = 0.0000
# tote =     10;  Entrytime =   540.3129;  Column = 31;  Mean throughput =0.018508  Mean flowtime = 0.0000
# tote =     67;  Entrytime =  4047.8714;  Column = 13;  Mean throughput =0.016552  Mean flowtime = 0.0000
# tote =     68;  Entrytime =  4077.1974;  Column = 50;  Mean throughput =0.016678  Mean flowtime = 0.0000
# tote =     69;  Entrytime =  4121.9959;  Column = 41;  Mean throughput =0.016739  Mean flowtime = 0.0000
# tote =     70;  Entrytime =  4207.9489;  Column = 43;  Mean throughput =0.016635  Mean flowtime = 0.0000
# tote =     71;  Entrytime =  4282.3139;  Column = 28;  Mean throughput =0.016580  Mean flowtime = 0.0000
# tote =     72;  Entrytime =  4583.7189;  Column = 52;  Mean throughput =0.015708  Mean flowtime = 0.0000
# tote =     73;  Entrytime =  4621.6735;  Column = 16;  Mean throughput =0.015795  Mean flowtime = 0.0000
# tote =     74;  Entrytime =  4643.6862;  Column = 53;  Mean throughput =0.015936  Mean flowtime = 0.0000
# tote =     75;  Entrytime =  4684.2449;  Column =  2;  Mean throughput =0.016011  Mean flowtime = 0.0000
# tote =     76;  Entrytime =  4703.6780;  Column = 47;  Mean throughput =0.016158  Mean flowtime = 0.0000
# tote =     77;  Entrytime =  4880.0198;  Column = 51;  Mean throughput =0.015779  Mean flowtime = 0.0000
# tote =     78;  Entrytime =  4886.3972;  Column = 14;  Mean throughput =0.015963  Mean flowtime = 0.0000
# tote =     79;  Entrytime =  4953.5242;  Column =  0;  Mean throughput =0.015948  Mean flowtime = 0.0000
# tote =     80;  Entrytime =  4979.6096;  Column = 31;  Mean throughput =0.016066  Mean flowtime = 0.0000
# tote =     81;  Entrytime =  5022.5768;  Column = 12;  Mean throughput =0.016127  Mean flowtime = 0.0000
# tote =     82;  Entrytime =  5065.0876;  Column = 28;  Mean throughput =0.016189  Mean flowtime = 0.0000
# tote =     83;  Entrytime =  5108.7374;  Column = 46;  Mean throughput =0.016247  Mean flowtime = 0.0000
# tote =     84;  Entrytime =  5131.4513;  Column = 22;  Mean throughput =0.016370  Mean flowtime = 0.0000
# tote =     85;  Entrytime =  5305.7594;  Column = 14;  Mean throughput =0.016020  Mean flowtime = 0.0000
# tote =     86;  Entrytime =  5584.9098;  Column = 18;  Mean throughput =0.015399  Mean flowtime = 0.0000
# tote =     87;  Entrytime =  5587.7811;  Column = 21;  Mean throughput =0.015570  Mean flowtime = 0.0000
# tote =     88;  Entrytime =  5615.2421;  Column = 46;  Mean throughput =0.015672  Mean flowtime = 0.0000
# tote =     89;  Entrytime =  5788.8910;  Column = 30;  Mean throughput =0.015374  Mean flowtime = 0.0000
# tote =     90;  Entrytime =  6409.5489;  Column = 29;  Mean throughput =0.014042  Mean flowtime = 0.0000
# tote =     91;  Entrytime =  6415.3884;  Column = 17;  Mean throughput =0.014185  Mean flowtime = 0.0000
# tote =     92;  Entrytime =  6543.6120;  Column = 40;  Mean throughput =0.014060  Mean flowtime = 0.0000
# tote =     93;  Entrytime =  6569.6101;  Column = 13;  Mean throughput =0.014156  Mean flowtime = 0.0000
# tote =     94;  Entrytime =  6611.2405;  Column = 45;  Mean throughput =0.014218  Mean flowtime = 0.0000
# tote =     95;  Entrytime =  6649.7195;  Column = 40;  Mean throughput =0.014286  Mean flowtime = 0.0000
# tote =     96;  Entrytime =  6681.3662;  Column = 44;  Mean throughput =0.014368  Mean flowtime = 0.0000
# tote =     97;  Entrytime =  6726.0346;  Column = 34;  Mean throughput =0.014422  Mean flowtime = 0.0000
# tote =     98;  Entrytime =  6803.6502;  Column = 49;  Mean throughput =0.014404  Mean flowtime = 0.0000
# tote =     99;  Entrytime =  6865.5747;  Column = 28;  Mean throughput =0.014420  Mean flowtime = 0.0000
# tote =    100;  Entrytime =  6922.2694;  Column = 22;  Mean throughput =0.014446  Mean flowtime = 0.0000
# simulation has ended

# %% [markdown]
# ## 6.2 Exercise 2: Demand Buffer (5 points)
# Next, we include the Demand buffer which is modelled as a standard FIFO buffer with infinite capacity.
#
# a. Determine (analytically) the throughput and flow time that should result from your model with only the generator process, demand buffer, and the exit process.

# %% [markdown]
# Answer: ...

# %% [markdown]
# b. Complete the simulation code in the template below. Confirm that your simulations produces the same throughput and flow time as determined previously.
#
# Note: The previously defined variables and functions remain unchanged, only the Demand Buffer is added, and the main code is changed.

# %% [markdown]
# Answer: ...

# %%
# =================================
# Demand Buffer
# =================================
@process
def Demand_Buffer(env, c_in, c_out):
    xs = [] # list of totes
 
# =================================
# Our code
    while True:
        sending = c_out.send(xs[0]) if len(xs)>0 else None
        receiving = c_in.receive()
        x = yield env.select(sending, receiving)
        if selected(receiving):
            xs = xs + [x]
        if selected(sending):
            xs = xs[1:]
        # print(f"The buffer contains {len(xs)} item(s)")
# =================================

# =================================
# Model
# =================================
def model():
    # Variables
    arrive = 70.0             # inter arrival time of requests
    depth  = 55               # the number of columns
    
    number_of_orders = 10000  # the number of orders to process
    
    env = Environment()
    a = Channel(env)
    b = Channel(env)
    G = Generator(env, a, arrive, depth)
    D = Demand_Buffer(env, a, b)
    E = Exit(env, b, number_of_orders)
    env.run(until=E)
    print ("simulation has ended")
    
# =================================
# Main
# =================================
model()
# Out:
# tote =      1;  Entrytime =     0.0000;  Column = 24;  Mean throughput =    N.A.  Mean flowtime = 0.0000
# tote =      2;  Entrytime =   114.2277;  Column =  4;  Mean throughput =0.017509  Mean flowtime = 0.0000
# tote =      3;  Entrytime =   292.8366;  Column = 28;  Mean throughput =0.010245  Mean flowtime = 0.0000
# tote =      4;  Entrytime =   306.2137;  Column = 19;  Mean throughput =0.013063  Mean flowtime = 0.0000
# tote =      5;  Entrytime =   396.6803;  Column =  7;  Mean throughput =0.012605  Mean flowtime = 0.0000
# tote =      6;  Entrytime =   453.0098;  Column = 23;  Mean throughput =0.013245  Mean flowtime = 0.0000
# tote =      7;  Entrytime =   648.4964;  Column = 37;  Mean throughput =0.010794  Mean flowtime = 0.0000
# tote =      8;  Entrytime =   670.1354;  Column = 10;  Mean throughput =0.011938  Mean flowtime = 0.0000
# tote =      9;  Entrytime =   741.5264;  Column =  0;  Mean throughput =0.012137  Mean flowtime = 0.0000
# tote =     10;  Entrytime =   826.4618;  Column = 47;  Mean throughput =0.012100  Mean flowtime = 0.0000
# tote =     67;  Entrytime =  5770.9063;  Column = 28;  Mean throughput =0.011610  Mean flowtime = 0.0000
# tote =     68;  Entrytime =  5829.8619;  Column = 25;  Mean throughput =0.011664  Mean flowtime = 0.0000
# tote =     69;  Entrytime =  5838.1877;  Column =  6;  Mean throughput =0.011819  Mean flowtime = 0.0000
# tote =     70;  Entrytime =  5877.5664;  Column = 15;  Mean throughput =0.011910  Mean flowtime = 0.0000
# tote =     71;  Entrytime =  5921.4310;  Column = 48;  Mean throughput =0.011990  Mean flowtime = 0.0000
# tote =     72;  Entrytime =  5929.3393;  Column = 50;  Mean throughput =0.012143  Mean flowtime = 0.0000
# tote =     73;  Entrytime =  5946.9766;  Column = 21;  Mean throughput =0.012275  Mean flowtime = 0.0000
# tote =     74;  Entrytime =  6034.0376;  Column = 42;  Mean throughput =0.012264  Mean flowtime = 0.0000
# tote =     75;  Entrytime =  6072.9324;  Column = 12;  Mean throughput =0.012350  Mean flowtime = 0.0000
# tote =     76;  Entrytime =  6108.0863;  Column = 48;  Mean throughput =0.012443  Mean flowtime = 0.0000
# tote =     77;  Entrytime =  6161.8659;  Column = 33;  Mean throughput =0.012496  Mean flowtime = 0.0000
# tote =     78;  Entrytime =  6334.0787;  Column =  1;  Mean throughput =0.012314  Mean flowtime = 0.0000
# tote =     79;  Entrytime =  6374.6616;  Column = 41;  Mean throughput =0.012393  Mean flowtime = 0.0000
# tote =     80;  Entrytime =  6410.6129;  Column = 29;  Mean throughput =0.012479  Mean flowtime = 0.0000
# tote =     81;  Entrytime =  6412.2368;  Column = 40;  Mean throughput =0.012632  Mean flowtime = 0.0000
# tote =     82;  Entrytime =  6488.1594;  Column = 16;  Mean throughput =0.012638  Mean flowtime = 0.0000
# tote =     83;  Entrytime =  6511.5187;  Column = 30;  Mean throughput =0.012747  Mean flowtime = 0.0000
# tote =     84;  Entrytime =  6694.0519;  Column = 39;  Mean throughput =0.012548  Mean flowtime = 0.0000
# tote =     85;  Entrytime =  6734.9461;  Column = 41;  Mean throughput =0.012621  Mean flowtime = 0.0000
# tote =     86;  Entrytime =  6773.7230;  Column = 24;  Mean throughput =0.012696  Mean flowtime = 0.0000
# tote =     87;  Entrytime =  6783.6232;  Column = 52;  Mean throughput =0.012825  Mean flowtime = 0.0000
# tote =     88;  Entrytime =  6836.9561;  Column = 25;  Mean throughput =0.012871  Mean flowtime = 0.0000
# tote =     89;  Entrytime =  6865.6153;  Column = 25;  Mean throughput =0.012963  Mean flowtime = 0.0000
# tote =     90;  Entrytime =  6872.3098;  Column = 32;  Mean throughput =0.013096  Mean flowtime = 0.0000
# tote =     91;  Entrytime =  7025.2996;  Column = 31;  Mean throughput =0.012953  Mean flowtime = 0.0000
# tote =     92;  Entrytime =  7034.8120;  Column = 16;  Mean throughput =0.013078  Mean flowtime = 0.0000
# tote =     93;  Entrytime =  7044.4694;  Column = 54;  Mean throughput =0.013202  Mean flowtime = 0.0000
# tote =     94;  Entrytime =  7124.1120;  Column = 20;  Mean throughput =0.013195  Mean flowtime = 0.0000
# tote =    291;  Entrytime =  20408.3594;  Column =  1;  Mean throughput =0.014259  Mean flowtime = 0.0000
# tote =    292;  Entrytime =  20482.5237;  Column =  7;  Mean throughput =0.014256  Mean flowtime = 0.0000
# tote =    293;  Entrytime =  20653.1146;  Column = 15;  Mean throughput =0.014187  Mean flowtime = 0.0000
# tote =    294;  Entrytime =  20657.2153;  Column = 51;  Mean throughput =0.014232  Mean flowtime = 0.0000
# tote =    295;  Entrytime =  20704.7883;  Column = 51;  Mean throughput =0.014248  Mean flowtime = 0.0000
# tote =    296;  Entrytime =  20924.2073;  Column = 20;  Mean throughput =0.014146  Mean flowtime = 0.0000
# tote =    297;  Entrytime =  20941.1791;  Column = 31;  Mean throughput =0.014183  Mean flowtime = 0.0000
# tote =    298;  Entrytime =  21015.9045;  Column =  2;  Mean throughput =0.014180  Mean flowtime = 0.0000
# tote =    299;  Entrytime =  21029.1658;  Column = 19;  Mean throughput =0.014218  Mean flowtime = 0.0000
# tote =    300;  Entrytime =  21105.2750;  Column = 13;  Mean throughput =0.014214  Mean flowtime = 0.0000
# tote =    301;  Entrytime =  21316.4004;  Column =  5;  Mean throughput =0.014121  Mean flowtime = 0.0000
# tote =    302;  Entrytime =  21450.0179;  Column = 10;  Mean throughput =0.014079  Mean flowtime = 0.0000
# tote =    303;  Entrytime =  21474.6768;  Column = 44;  Mean throughput =0.014110  Mean flowtime = 0.0000
# tote =    304;  Entrytime =  21555.2910;  Column = 14;  Mean throughput =0.014103  Mean flowtime = 0.0000
# tote =    305;  Entrytime =  21571.7521;  Column = 30;  Mean throughput =0.014139  Mean flowtime = 0.0000
# tote =    306;  Entrytime =  21584.0227;  Column = 49;  Mean throughput =0.014177  Mean flowtime = 0.0000
# tote =    307;  Entrytime =  21584.7681;  Column = 47;  Mean throughput =0.014223  Mean flowtime = 0.0000
# tote =    308;  Entrytime =  21611.1794;  Column = 12;  Mean throughput =0.014252  Mean flowtime = 0.0000
# tote =    309;  Entrytime =  21626.3510;  Column = 21;  Mean throughput =0.014288  Mean flowtime = 0.0000
# tote =    310;  Entrytime =  21758.8373;  Column =  9;  Mean throughput =0.014247  Mean flowtime = 0.0000
# tote =    311;  Entrytime =  21794.0466;  Column = 33;  Mean throughput =0.014270  Mean flowtime = 0.0000
# tote =    312;  Entrytime =  21822.7458;  Column = 48;  Mean throughput =0.014297  Mean flowtime = 0.0000
# tote =    313;  Entrytime =  21878.4306;  Column = 20;  Mean throughput =0.014306  Mean flowtime = 0.0000
# tote =    314;  Entrytime =  21898.5733;  Column = 54;  Mean throughput =0.014339  Mean flowtime = 0.0000
# tote =    315;  Entrytime =  21903.5505;  Column = 46;  Mean throughput =0.014381  Mean flowtime = 0.0000
# tote =    316;  Entrytime =  21906.2705;  Column = 34;  Mean throughput =0.014425  Mean flowtime = 0.0000
# tote =    317;  Entrytime =  22006.3945;  Column = 40;  Mean throughput =0.014405  Mean flowtime = 0.0000
# tote =    318;  Entrytime =  22017.9584;  Column =  2;  Mean throughput =0.014443  Mean flowtime = 0.0000
  Mean throughput =0.014398  Mean flowtime = 0.0000
# tote =   9979;  Entrytime =  693032.8418;  Column =  7;  Mean throughput =0.014399  Mean flowtime = 0.0000
# tote =   9980;  Entrytime =  693165.4508;  Column = 43;  Mean throughput =0.014398  Mean flowtime = 0.0000
# tote =   9981;  Entrytime =  693237.5999;  Column = 24;  Mean throughput =0.014398  Mean flowtime = 0.0000
# tote =   9982;  Entrytime =  693242.3395;  Column = 34;  Mean throughput =0.014399  Mean flowtime = 0.0000
# tote =   9983;  Entrytime =  693377.5420;  Column = 12;  Mean throughput =0.014398  Mean flowtime = 0.0000
# tote =   9984;  Entrytime =  693455.2774;  Column = 47;  Mean throughput =0.014397  Mean flowtime = 0.0000
# tote =   9985;  Entrytime =  693457.9353;  Column = 24;  Mean throughput =0.014399  Mean flowtime = 0.0000
# tote =   9986;  Entrytime =  693665.6719;  Column = 42;  Mean throughput =0.014396  Mean flowtime = 0.0000
# tote =   9987;  Entrytime =  693707.3086;  Column = 28;  Mean throughput =0.014397  Mean flowtime = 0.0000
# tote =   9988;  Entrytime =  693777.3658;  Column = 29;  Mean throughput =0.014397  Mean flowtime = 0.0000
# tote =   9989;  Entrytime =  693809.0261;  Column = 35;  Mean throughput =0.014397  Mean flowtime = 0.0000
# tote =   9990;  Entrytime =  693901.0567;  Column = 39;  Mean throughput =0.014397  Mean flowtime = 0.0000
# tote =   9991;  Entrytime =  693935.4153;  Column = 12;  Mean throughput =0.014398  Mean flowtime = 0.0000
# tote =   9992;  Entrytime =  693961.4936;  Column = 44;  Mean throughput =0.014398  Mean flowtime = 0.0000
# tote =   9993;  Entrytime =  694062.6085;  Column =  6;  Mean throughput =0.014398  Mean flowtime = 0.0000
# tote =   9994;  Entrytime =  694083.9444;  Column = 44;  Mean throughput =0.014399  Mean flowtime = 0.0000
# tote =   9995;  Entrytime =  694127.0291;  Column = 25;  Mean throughput =0.014399  Mean flowtime = 0.0000
# tote =   9996;  Entrytime =  694144.5219;  Column = 48;  Mean throughput =0.014400  Mean flowtime = 0.0000
# tote =   9997;  Entrytime =  694208.0634;  Column = 18;  Mean throughput =0.014401  Mean flowtime = 0.0000
# tote =   9998;  Entrytime =  694276.7569;  Column = 13;  Mean throughput =0.014401  Mean flowtime = 0.0000
# tote =   9999;  Entrytime =  694279.6967;  Column =  6;  Mean throughput =0.014402  Mean flowtime = 0.0000
# tote =  10000;  Entrytime =  694442.3585;  Column = 13;  Mean throughput =0.014400  Mean flowtime = 0.0000
# simulation has ended

# %% [markdown]
# ## 6.3 Exercise 3: Vehicle as machine (5 points)
# Next, we include the Vehicle which as a first attempt is modelled as a standard machine with a deterministic processing time of 40.0 seconds. The simulation code for the simplified vehicle is given below.
#
# Note: The previously defined variables and functions remain unchanged, only the Vehicle is added, and the main code is changed.

# %%
# =================================
# Vehicle
# =================================
@process
def Vehicle(env, c_in, c_out):
    tp = 40.0
    while True:
        x = yield env.execute(c_in.receive())
        yield env.timeout(tp)
        yield env.execute(c_out.send(x))

# =================================
# Model
# =================================
def model():
    # Variables 
    arrive = 70.0             # inter arrival time of requests
    depth  = 55               # the number of columns

    number_of_orders = 100    # the number of orders to process
    
    env = Environment()
    a = Channel(env)
    b = Channel(env)
    c = Channel(env)
    G = Generator(env, a, arrive, depth)
    D = Demand_Buffer(env, a, b)
    V = Vehicle(env, b, c)
    E = Exit(env, c, number_of_orders)
    env.run(until=E)
    print ("simulation has ended")

# =================================
# Main
# =================================
model()
# Out:
# tote =      1;  Entrytime =     0.0000;  Column = 44;  Mean throughput =0.025000  Mean flowtime = 40.0000
# tote =      2;  Entrytime =    25.9938;  Column =  7;  Mean throughput =0.025000  Mean flowtime = 47.0031
# tote =      3;  Entrytime =    35.7144;  Column = 21;  Mean throughput =0.025000  Mean flowtime = 59.4306
# tote =      4;  Entrytime =    84.0571;  Column = 36;  Mean throughput =0.025000  Mean flowtime = 63.5587
# tote =      5;  Entrytime =   207.3382;  Column = 15;  Mean throughput =0.020215  Mean flowtime = 58.8469
# tote =      6;  Entrytime =   276.7419;  Column = 15;  Mean throughput =0.018943  Mean flowtime = 55.7058
# tote =      7;  Entrytime =   377.5940;  Column =  4;  Mean throughput =0.016763  Mean flowtime = 53.4621
# tote =      8;  Entrytime =   379.5597;  Column = 44;  Mean throughput =0.017483  Mean flowtime = 56.5336
# tote =      9;  Entrytime =   414.8933;  Column = 51;  Mean throughput =0.018087  Mean flowtime = 59.4411
# tote =     10;  Entrytime =   575.7579;  Column = 40;  Mean throughput =0.016240  Mean flowtime = 57.4970
# tote =     11;  Entrytime =   691.5539;  Column = 30;  Mean throughput =0.015036  Mean flowtime = 55.9063
# tote =     12;  Entrytime =   796.3742;  Column = 46;  Mean throughput =0.014348  Mean flowtime = 54.5808
# tote =     13;  Entrytime =   910.4983;  Column = 14;  Mean throughput =0.013677  Mean flowtime = 53.4592
# tote =     14;  Entrytime =   944.7326;  Column = 16;  Mean throughput =0.014134  Mean flowtime = 52.9097
# tote =     15;  Entrytime =   980.5910;  Column = 38;  Mean throughput =0.014556  Mean flowtime = 52.7095
# tote =     16;  Entrytime =  1300.3048;  Column = 34;  Mean throughput =0.011938  Mean flowtime = 51.9152
# tote =     17;  Entrytime =  1304.7754;  Column = 53;  Mean throughput =0.012316  Mean flowtime = 53.3042
# tote =     18;  Entrytime =  1439.7696;  Column =  9;  Mean throughput =0.012164  Mean flowtime = 52.5651
# tote =     19;  Entrytime =  1577.1317;  Column = 36;  Mean throughput =0.011749  Mean flowtime = 51.9038
# tote =     20;  Entrytime =  1615.8688;  Column = 19;  Mean throughput =0.012069  Mean flowtime = 51.3718
# tote =     21;  Entrytime =  1635.7054;  Column = 29;  Mean throughput =0.012374  Mean flowtime = 51.8505
# tote =     22;  Entrytime =  1652.2095;  Column = 14;  Mean throughput =0.012665  Mean flowtime = 53.3538
# tote =     23;  Entrytime =  1679.2481;  Column =  0;  Mean throughput =0.012942  Mean flowtime = 55.2899
# tote =     24;  Entrytime =  1785.7923;  Column = 42;  Mean throughput =0.013145  Mean flowtime = 54.6528
# tote =     25;  Entrytime =  1868.6841;  Column = 48;  Mean throughput =0.013098  Mean flowtime = 54.0667
# tote =     26;  Entrytime =  1987.4093;  Column = 30;  Mean throughput =0.012824  Mean flowtime = 53.5257
# tote =     27;  Entrytime =  2082.6493;  Column =  0;  Mean throughput =0.012720  Mean flowtime = 53.0247
# tote =     28;  Entrytime =  2114.8472;  Column = 51;  Mean throughput =0.012947  Mean flowtime = 52.8382
# tote =     29;  Entrytime =  2317.0691;  Column = 39;  Mean throughput =0.012303  Mean flowtime = 52.3955
# tote =     30;  Entrytime =  2366.2717;  Column =  9;  Mean throughput =0.012467  Mean flowtime = 51.9823
# tote =     31;  Entrytime =  2375.1153;  Column = 49;  Mean throughput =0.012672  Mean flowtime = 52.6008
# tote =     32;  Entrytime =  2636.6022;  Column =  8;  Mean throughput =0.011955  Mean flowtime = 52.2071
# tote =     61;  Entrytime =  4171.6312;  Column = 52;  Mean throughput =0.014031  Mean flowtime = 67.5419
# tote =     62;  Entrytime =  4178.0441;  Column = 14;  Mean throughput =0.014131  Mean flowtime = 69.8309
# tote =     63;  Entrytime =  4250.0873;  Column = 13;  Mean throughput =0.014229  Mean flowtime = 71.5385
# tote =     64;  Entrytime =  4268.9765;  Column =  5;  Mean throughput =0.014326  Mean flowtime = 73.5227
# tote =     65;  Entrytime =  4537.4502;  Column = 52;  Mean throughput =0.014200  Mean flowtime = 73.0070
# tote =     66;  Entrytime =  4579.1769;  Column = 30;  Mean throughput =0.014288  Mean flowtime = 72.5068
# tote =     67;  Entrytime =  4662.1617;  Column = 35;  Mean throughput =0.014249  Mean flowtime = 72.0217
# tote =     68;  Entrytime =  4805.1292;  Column = 53;  Mean throughput =0.014035  Mean flowtime = 71.5508
# tote =     69;  Entrytime =  4816.0563;  Column = 39;  Mean throughput =0.014124  Mean flowtime = 71.5149
# tote =     70;  Entrytime =  4854.6132;  Column = 22;  Mean throughput =0.014213  Mean flowtime = 71.5006
# tote =     71;  Entrytime =  4883.4007;  Column = 15;  Mean throughput =0.014300  Mean flowtime = 71.6446
# tote =     72;  Entrytime =  4944.8002;  Column = 53;  Mean throughput =0.014385  Mean flowtime = 71.4875
# tote =     73;  Entrytime =  4997.1413;  Column = 53;  Mean throughput =0.014469  Mean flowtime = 71.1656
# tote =     74;  Entrytime =  5046.1392;  Column = 21;  Mean throughput =0.014549  Mean flowtime = 70.7444
# tote =     75;  Entrytime =  5063.8187;  Column = 34;  Mean throughput =0.014631  Mean flowtime = 70.6321
# tote =     76;  Entrytime =  5223.1698;  Column = 26;  Mean throughput =0.014440  Mean flowtime = 70.2290
# tote =     77;  Entrytime =  5293.2122;  Column = 41;  Mean throughput =0.014438  Mean flowtime = 69.8365
# tote =     78;  Entrytime =  5647.9741;  Column =  4;  Mean throughput =0.013713  Mean flowtime = 69.4539
# tote =     79;  Entrytime =  5813.7690;  Column = 47;  Mean throughput =0.013496  Mean flowtime = 69.0811
# tote =     80;  Entrytime =  5877.9868;  Column = 30;  Mean throughput =0.013518  Mean flowtime = 68.7176
# tote =     81;  Entrytime =  5898.8496;  Column = 19;  Mean throughput =0.013595  Mean flowtime = 68.5993
# tote =     82;  Entrytime =  5947.1210;  Column = 20;  Mean throughput =0.013671  Mean flowtime = 68.3830
# tote =     83;  Entrytime =  5984.6293;  Column = 31;  Mean throughput =0.013746  Mean flowtime = 68.2020
# tote =     84;  Entrytime =  5992.7600;  Column =  9;  Mean throughput =0.013820  Mean flowtime = 68.4047
# tote =     85;  Entrytime =  6137.9302;  Column = 50;  Mean throughput =0.013759  Mean flowtime = 68.0705
# tote =     86;  Entrytime =  6292.8074;  Column = 53;  Mean throughput =0.013580  Mean flowtime = 67.7441
# tote =     87;  Entrytime =  6321.6695;  Column = 19;  Mean throughput =0.013652  Mean flowtime = 67.5532
# tote =     88;  Entrytime =  6327.1148;  Column = 12;  Mean throughput =0.013723  Mean flowtime = 67.7594
# tote =     89;  Entrytime =  6406.9331;  Column =  4;  Mean throughput =0.013792  Mean flowtime = 67.5135
# tote =     90;  Entrytime =  6430.6905;  Column = 48;  Mean throughput =0.013861  Mean flowtime = 67.4535
# tote =     91;  Entrytime =  6495.9567;  Column =  1;  Mean throughput =0.013923  Mean flowtime = 67.1518
# tote =     92;  Entrytime =  6557.2914;  Column = 11;  Mean throughput =0.013945  Mean flowtime = 66.8567
# tote =     93;  Entrytime =  6575.9799;  Column = 44;  Mean throughput =0.014012  Mean flowtime = 66.7971
# tote =     94;  Entrytime =  6743.5200;  Column = 37;  Mean throughput =0.013857  Mean flowtime = 66.5120
# tote =     95;  Entrytime =  6764.7610;  Column = 13;  Mean throughput =0.013922  Mean flowtime = 66.4304
# tote =     96;  Entrytime =  6825.5196;  Column =  1;  Mean throughput =0.013983  Mean flowtime = 66.1551
# tote =     97;  Entrytime =  6882.1425;  Column =  3;  Mean throughput =0.014013  Mean flowtime = 65.8854
# tote =     98;  Entrytime =  7019.7942;  Column = 49;  Mean throughput =0.013881  Mean flowtime = 65.6213
# tote =     99;  Entrytime =  7053.3913;  Column =  9;  Mean throughput =0.013944  Mean flowtime = 65.4272
# tote =    100;  Entrytime =  7125.1120;  Column =  1;  Mean throughput =0.013957  Mean flowtime = 65.1729
# simulation has ended

# %% [markdown]
# a. Determine (analytically) the throughput and flow time that should result from your model with only the generator process, demand buffer, vehicle and the exit process.

# %% [markdown]
# Answer: ...

# %% [markdown]
# b. Run your simulation at least 10 times. Confirm that your analytically determined throughput and flow time are correct.  What is the range of outcomes for the throughput? Determine (roughly/ by trial and error) the number of orders required to get good estimates for the flow time (first three **non-zero** digits are correct).

# %% [markdown]
# Answer: ...

# %% [markdown]
# ## 6.4 Exercise 4: Vehicle accurately modelled (15 points)
# Assume that a vehicle starts from the buffer. If it has to go to column $i \in \{0, depth - 1\}$, it needs to drive a distance $dv \cdot (i + 1)$, pick up the tote, drive back, and deliver the tote to the buffer. For driving the required distance, the vehicle first goes with a constant acceleration $av$ $[m/s^2]$ until it reaches its maximum velocity $vmaxv$, then it moves with this velocity and decelerates with a constant deceleration $av$ to approach its destination point. If the tote is located too close to the end of the aisle, it is possible that the vehicle will not reach its maximum speed.
#
# a. From this information, (analytically) determine the time (in seconds) it takes a vehicle to move a given distance of $x$ meters. To that end, first determine from the acceleration profile the travelled distance as function of time. From that you can determine the time required to travel a given distance. Express the time spent moving (one way) $t_{moving}$ in terms of $x$, $av$ and $vmaxv$.

# %% [markdown]
# Answer: ...
#
#
# $
# t_{moving}(x) =
#     \begin{cases}
#       ... \ , & \text{for}\ x \leq \ ... \ , \\
#       ... \ , & \text{for}\ x >    \ ... \ .
#     \end{cases}
# $

# %% [markdown]
# b. Next, if loading and unloading a tote both take $lv$ seconds, determine (analytically) the time it takes a vehicle, starting from the buffer, to pick up a tote from column $i \in \{0, depth - 1\}$ and deliver it to the buffer. Express the total travel time $t_{total}$ in terms of $i$, $dv$, $lv$, $av$, and $vmaxv$.

# %% [markdown]
# Answer: ...
#
# $
# t_{total}(i) =
#     \begin{cases}
#       ... \ , & \text{for} \ ... \leq \ ... \ , \\
#       ... \ , & \text{for} \ ... >    \ ... \ .
#     \end{cases}
# $

# %% [markdown]
# c. First determine analytically the mean and variance of this total travel time $t_{total}$ for a random (uniformly distributed) column. Then, calculate the numerical mean and variance for the following parameters: $depth = 55$, $lv = 3.0$, $dv = 0.5$, $vmaxv = 1.5$, and $av = 1.0$, using the code below.

# %% [markdown]
# Analytical answer:
#
# mean $ = \ ... $
#
# variance  $ = \ ... $

# %% [markdown]
# Numerical answer:
#
# mean $ = \ ... $
#
# variance  $ = \ ... $

# %%
def exc4c():
    depth = 55
    lv = 3.0
    dv = 0.5
    vmaxv = 1.5
    av = 1.0
    
    # our code
    
    times = [];
    
    for _ in range(100):
        
        i = random.randint(0, depth)        
        
        if i <= (vmaxv**2 / (dv*av)) - 1:
            ttotal = 4*((dv*(i+1))/av)**0.5 + 2*lv
        elif i > (vmaxv**2 / (dv*av)) - 1:
            ttotal = 2*(vmaxv/av + (dv*(i+1))/vmaxv) + 2*lv
        
        times.append(ttotal)

    
    mean = sum(times)/len(times);
    deviations = [(x - mean) ** 2 for x in times]
    variance = sum(deviations) / len(times)

    # ...

        
    print(f"the mean is {mean}")
    print(f"the variance is {variance}")

exc4c()
# Out:
# the mean is 26.937685217196098
# the variance is 107.03000441227465

# %% [markdown]
# d. Determine (analytically) the throughput and flow time that should result from your model with only the generator process, demand buffer, vehicle and the exit process.

# %% [markdown]
# Answer: ...
#
# Throughput $ = \ ...$
#
# Flowtime   $ = \ ...$

# %% [markdown]
# e. Complete the simulation code in the template below, incorporating the actual time a vehicle requires for picking up a tote and delivering it to the buffer. Confirm that your simulations produce the same throughput and flow time as in your calculations.
#
# Note: the previously defined function processes remain unchanged, only the Vehicle and model need to be redefined.

# %%
# =================================
# Vehicle definition
# =================================
@process
def Vehicle(env, c_in, c_out, lv, dv, vmaxv, av):
    
    #our code
    depth = 55; # Why don't they give this value??
    
    
    while True:
        x = yield env.execute(c_in.receive())
        i = random.randint(0, depth) 
        
        #i = yield env.execute(c_in.receive())

        if i <= (vmaxv**2 / (dv*av)) - 1:
            tp = 4*((dv*(i+1))/av)**0.5 + 2*lv
        elif i > (vmaxv**2 / (dv*av)) - 1:
            tp = 2*(vmaxv/av + (dv*(i+1))/vmaxv) + 2*lv

        yield env.timeout(tp)
        yield env.execute(c_out.send(x))

    #our code

# =================================
# Main
# =================================
def model():
    # Variables 
    arrive = 70.0             # inter arrival time of requests
    depth  = 55               # the number of columns
    lv = 3.0                  # time to load/unload the vehicle
    dv = 0.5                  # unit width clearance
    vmaxv = 1.5               # maximum velocity of the vehicle
    av = 1.0                  # acceleration/deceleration of the vehicle
    
    number_of_orders = 1000    # the number of orders to process
    
    env = Environment()
    a = Channel(env)
    b = Channel(env)
    c = Channel(env)
    G = Generator(env, a, arrive, depth)
    D = Demand_Buffer(env, a, b)
    V = Vehicle(env, b, c, lv, dv, vmaxv, av)
    E = Exit(env, c, number_of_orders)
    env.run(until=E)
    print ("simulation has ended")

# =================================
# Main
# =================================
model()
# Out:
# tote =      1;  Entrytime =     0.0000;  Column = 24;  Mean throughput =0.050847  Mean flowtime = 19.6667
# tote =      2;  Entrytime =   151.0827;  Column = 42;  Mean throughput =0.010787  Mean flowtime = 27.0000
# tote =      3;  Entrytime =   171.2320;  Column = 16;  Mean throughput =0.013611  Mean flowtime = 34.3947
# tote =      4;  Entrytime =   265.0639;  Column = 22;  Mean throughput =0.013727  Mean flowtime = 32.3794
# tote =      5;  Entrytime =   555.1376;  Column = 22;  Mean throughput =0.008709  Mean flowtime = 29.7035
# tote =      6;  Entrytime =   625.3284;  Column =  7;  Mean throughput =0.008969  Mean flowtime = 32.0307
# tote =      7;  Entrytime =   655.5585;  Column =  8;  Mean throughput =0.010165  Mean flowtime = 32.1839
# tote =      8;  Entrytime =   703.1056;  Column = 30;  Mean throughput =0.011008  Mean flowtime = 31.1193
# tote =      9;  Entrytime =   722.0697;  Column = 42;  Mean throughput =0.012155  Mean flowtime = 29.7026
# tote =     10;  Entrytime =   818.5845;  Column = 40;  Mean throughput =0.011616  Mean flowtime = 30.9657
# tote =     11;  Entrytime =   869.4270;  Column = 27;  Mean throughput =0.012475  Mean flowtime = 29.2718
# tote =     12;  Entrytime =   871.4898;  Column = 15;  Mean throughput =0.013157  Mean flowtime = 30.2162
# tote =     13;  Entrytime =  1124.9095;  Column = 18;  Mean throughput =0.011305  Mean flowtime = 29.8149
# tote =     14;  Entrytime =  1128.2433;  Column = 13;  Mean throughput =0.011762  Mean flowtime = 32.1138
# tote =     15;  Entrytime =  1129.0190;  Column = 23;  Mean throughput =0.012377  Mean flowtime = 35.4989
# tote =     16;  Entrytime =  1180.0095;  Column =  0;  Mean throughput =0.012798  Mean flowtime = 37.6698
# tote =     17;  Entrytime =  1216.8081;  Column =  7;  Mean throughput =0.013394  Mean flowtime = 38.5384
# tote =     18;  Entrytime =  1245.3967;  Column = 47;  Mean throughput =0.013808  Mean flowtime = 39.6295
# tote =     19;  Entrytime =  1263.8687;  Column =  9;  Mean throughput =0.014464  Mean flowtime = 40.1599
# tote =     20;  Entrytime =  1372.8667;  Column = 24;  Mean throughput =0.014321  Mean flowtime = 39.3353
# tote =     21;  Entrytime =  1382.3949;  Column =  6;  Mean throughput =0.014697  Mean flowtime = 39.6751
# tote =     22;  Entrytime =  1398.1853;  Column = 50;  Mean throughput =0.015118  Mean flowtime = 40.4633
# tote =     23;  Entrytime =  1419.5078;  Column =  5;  Mean throughput =0.015609  Mean flowtime = 41.0529
# tote =     24;  Entrytime =  1610.3707;  Column = 16;  Mean throughput =0.014510  Mean flowtime = 41.1618
# tote =     25;  Entrytime =  1623.3402;  Column =  2;  Mean throughput =0.014755  Mean flowtime = 42.3566
# tote =     26;  Entrytime =  1686.0150;  Column =  6;  Mean throughput =0.014977  Mean flowtime = 42.6514
# tote =     27;  Entrytime =  1695.7688;  Column = 16;  Mean throughput =0.015205  Mean flowtime = 44.0323
# tote =     28;  Entrytime =  1716.4149;  Column = 50;  Mean throughput =0.015475  Mean flowtime = 45.7796
# tote =     29;  Entrytime =  1777.6153;  Column = 47;  Mean throughput =0.015803  Mean flowtime = 46.1810
# tote =     30;  Entrytime =  1781.2241;  Column = 13;  Mean throughput =0.016204  Mean flowtime = 46.9799
# tote =     31;  Entrytime =  1854.7581;  Column = 17;  Mean throughput =0.016393  Mean flowtime = 46.6364
# tote =     32;  Entrytime =  2058.8055;  Column = 50;  Mean throughput =0.015240  Mean flowtime = 46.4603
# tote =     33;  Entrytime =  2063.9049;  Column = 37;  Mean throughput =0.015521  Mean flowtime = 46.9383
# tote =     34;  Entrytime =  2219.2634;  Column = 37;  Mean throughput =0.015087  Mean flowtime = 46.5676
# tote =     35;  Entrytime =  2340.2665;  Column = 24;  Mean throughput =0.014789  Mean flowtime = 45.9894
# tote =     36;  Entrytime =  2388.0398;  Column = 10;  Mean throughput =0.014989  Mean flowtime = 45.0916
# tote =     37;  Entrytime =  2513.6151;  Column = 38;  Mean throughput =0.014567  Mean flowtime = 44.5846
# tote =     38;  Entrytime =  2591.7629;  Column = 13;  Mean throughput =0.014474  Mean flowtime = 44.2973
# tote =     39;  Entrytime =  2657.3766;  Column = 21;  Mean throughput =0.014525  Mean flowtime = 43.8709
# tote =     40;  Entrytime =  2659.9382;  Column =  2;  Mean throughput =0.014829  Mean flowtime = 43.7101
# tote =     41;  Entrytime =  2760.8912;  Column = 10;  Mean throughput =0.014647  Mean flowtime = 43.5789
# tote =     42;  Entrytime =  2825.2269;  Column =  0;  Mean throughput =0.014705  Mean flowtime = 43.2794
# tote =     43;  Entrytime =  2926.7131;  Column =  3;  Mean throughput =0.014535  Mean flowtime = 43.0094
# tote =     44;  Entrytime =  2959.4325;  Column = 20;  Mean throughput =0.014674  Mean flowtime = 42.9182
# tote =     45;  Entrytime =  3037.3591;  Column = 21;  Mean throughput =0.014625  Mean flowtime = 42.8460
# tote =     46;  Entrytime =  3044.3013;  Column = 42;  Mean throughput =0.014826  Mean flowtime = 43.1839
# tote =     47;  Entrytime =  3067.2939;  Column = 41;  Mean throughput =0.015030  Mean flowtime = 43.5360
# tote =     48;  Entrytime =  3112.9249;  Column = 41;  Mean throughput =0.015257  Mean flowtime = 43.3186
# tote =     49;  Entrytime =  3353.2590;  Column = 27;  Mean throughput =0.014565  Mean flowtime = 42.6570
# tote =     50;  Entrytime =  3406.4926;  Column = 50;  Mean throughput =0.014500  Mean flowtime = 42.6372
# tote =     51;  Entrytime =  3508.9460;  Column = 42;  Mean throughput =0.014353  Mean flowtime = 42.6704
# tote =     52;  Entrytime =  3538.2428;  Column = 49;  Mean throughput =0.014513  Mean flowtime = 42.7095
# tote =     53;  Entrytime =  3649.4522;  Column = 20;  Mean throughput =0.014466  Mean flowtime = 42.1741
# tote =     54;  Entrytime =  3674.5578;  Column =  7;  Mean throughput =0.014591  Mean flowtime = 41.8808
# tote =     55;  Entrytime =  3896.9595;  Column = 48;  Mean throughput =0.014045  Mean flowtime = 41.4648
# tote =     56;  Entrytime =  4092.0424;  Column =  0;  Mean throughput =0.013580  Mean flowtime = 41.2898
# tote =     57;  Entrytime =  4174.7307;  Column = 45;  Mean throughput =0.013538  Mean flowtime = 41.1911
# tote =     58;  Entrytime =  4266.2009;  Column = 34;  Mean throughput =0.013478  Mean flowtime = 41.1189
# tote =     59;  Entrytime =  4309.9535;  Column = 17;  Mean throughput =0.013591  Mean flowtime = 40.9474
# tote =     60;  Entrytime =  4353.6941;  Column = 53;  Mean throughput =0.013736  Mean flowtime = 40.5038
# tote =     61;  Entrytime =  4389.6638;  Column = 22;  Mean throughput =0.013753  Mean flowtime = 40.5884
# tote =     62;  Entrytime =  4649.5557;  Column = 33;  Mean throughput =0.013220  Mean flowtime = 40.5843
# tote =     63;  Entrytime =  4661.9758;  Column = 15;  Mean throughput =0.013332  Mean flowtime = 40.9493
# tote =     64;  Entrytime =  4727.4936;  Column = 45;  Mean throughput =0.013431  Mean flowtime = 40.8980
# tote =     65;  Entrytime =  4900.6584;  Column = 47;  Mean throughput =0.013159  Mean flowtime = 40.8688
# tote =     66;  Entrytime =  4966.6957;  Column = 20;  Mean throughput =0.013199  Mean flowtime = 40.7597
# tote =     67;  Entrytime =  5027.6792;  Column = 45;  Mean throughput =0.013290  Mean flowtime = 40.3553
# tote =     68;  Entrytime =  5032.7278;  Column = 43;  Mean throughput =0.013445  Mean flowtime = 40.1288
# tote =     69;  Entrytime =  5097.3962;  Column = 11;  Mean throughput =0.013430  Mean flowtime = 40.1318
# tote =     70;  Entrytime =  5175.7944;  Column = 35;  Mean throughput =0.013475  Mean flowtime = 39.8299
# tote =     71;  Entrytime =  5502.3754;  Column = 28;  Mean throughput =0.012837  Mean flowtime = 39.6680
# tote =     72;  Entrytime =  5514.0565;  Column = 16;  Mean throughput =0.012933  Mean flowtime = 39.8529
# tote =     73;  Entrytime =  5563.9653;  Column = 17;  Mean throughput =0.013037  Mean flowtime = 39.7921
# tote =     74;  Entrytime =  5676.3892;  Column = 15;  Mean throughput =0.013010  Mean flowtime = 39.4119
# tote =     75;  Entrytime =  5722.3827;  Column = 24;  Mean throughput =0.013004  Mean flowtime = 39.4864
# tote =     76;  Entrytime =  5779.7245;  Column = 51;  Mean throughput =0.013063  Mean flowtime = 39.4712
# tote =     77;  Entrytime =  6083.7071;  Column =  5;  Mean throughput =0.012576  Mean flowtime = 39.4651
# tote =     78;  Entrytime =  6210.8248;  Column =  6;  Mean throughput =0.012511  Mean flowtime = 39.2626
# tote =     79;  Entrytime =  6269.4227;  Column = 53;  Mean throughput =0.012551  Mean flowtime = 39.0820
# tote =     80;  Entrytime =  6403.6786;  Column = 14;  Mean throughput =0.012443  Mean flowtime = 38.9143
# tote =     81;  Entrytime =  6462.7602;  Column = 30;  Mean throughput =0.012504  Mean flowtime = 38.6191
# tote =     82;  Entrytime =  6569.4048;  Column = 30;  Mean throughput =0.012408  Mean flowtime = 38.6237
# tote =     83;  Entrytime =  6591.5323;  Column = 16;  Mean throughput =0.012485  Mean flowtime = 38.8396
# tote =    112;  Entrytime =  8635.7020;  Column = 19;  Mean throughput =0.012940  Mean flowtime = 37.2448
# tote =    113;  Entrytime =  8655.3291;  Column = 12;  Mean throughput =0.013039  Mean flowtime = 37.0120
# tote =    114;  Entrytime =  8661.4194;  Column = 41;  Mean throughput =0.013135  Mean flowtime = 36.8439
# tote =    115;  Entrytime =  8789.0859;  Column = 43;  Mean throughput =0.013026  Mean flowtime = 36.8684
# tote =    116;  Entrytime =  9014.4394;  Column = 21;  Mean throughput =0.012830  Mean flowtime = 36.7833
# tote =    117;  Entrytime =  9113.4041;  Column = 44;  Mean throughput =0.012787  Mean flowtime = 36.7795
# tote =    118;  Entrytime =  9135.6485;  Column =  8;  Mean throughput =0.012850  Mean flowtime = 36.8669
# tote =    119;  Entrytime =  9192.4384;  Column =  0;  Mean throughput =0.012909  Mean flowtime = 36.7727
# tote =    120;  Entrytime =  9369.7637;  Column = 33;  Mean throughput =0.012759  Mean flowtime = 36.7635
# tote =    121;  Entrytime =  9444.0629;  Column = 35;  Mean throughput =0.012757  Mean flowtime = 36.7985
# tote =    122;  Entrytime =  9464.5500;  Column =  7;  Mean throughput =0.012808  Mean flowtime = 36.9957
# tote =    123;  Entrytime =  9526.3310;  Column = 30;  Mean throughput =0.012861  Mean flowtime = 37.0011
# tote =    124;  Entrytime =  9638.0587;  Column = 21;  Mean throughput =0.012837  Mean flowtime = 36.8774
# tote =    125;  Entrytime =  9679.9681;  Column = 53;  Mean throughput =0.012888  Mean flowtime = 36.7344
# tote =    126;  Entrytime =  9768.6986;  Column = 13;  Mean throughput =0.012846  Mean flowtime = 36.7577
# tote =    127;  Entrytime =  9847.1751;  Column = 47;  Mean throughput =0.012844  Mean flowtime = 36.7858
# tote =    128;  Entrytime =  9902.8810;  Column =  2;  Mean throughput =0.012883  Mean flowtime = 36.7563
# tote =    129;  Entrytime =  9945.3697;  Column = 18;  Mean throughput =0.012912  Mean flowtime = 36.8253
# tote =    130;  Entrytime =  10050.9279;  Column = 46;  Mean throughput =0.012876  Mean flowtime = 36.8934
# tote =    131;  Entrytime =  10243.3517;  Column = 12;  Mean throughput =0.012772  Mean flowtime = 36.7161
# tote =    132;  Entrytime =  10251.9879;  Column = 18;  Mean throughput =0.012845  Mean flowtime = 36.6199
# tote =    133;  Entrytime =  10291.3814;  Column = 20;  Mean throughput =0.012887  Mean flowtime = 36.5627
# tote =    134;  Entrytime =  10307.5942;  Column = 18;  Mean throughput =0.012971  Mean flowtime = 36.4599
# tote =    135;  Entrytime =  10373.0837;  Column = 48;  Mean throughput =0.012987  Mean flowtime = 36.3503
# tote =    136;  Entrytime =  10612.3078;  Column = 30;  Mean throughput =0.012775  Mean flowtime = 36.3305
# tote =    137;  Entrytime =  10694.0794;  Column = 45;  Mean throughput =0.012792  Mean flowtime = 36.1797
# tote =    138;  Entrytime =  10759.8337;  Column = 45;  Mean throughput =0.012778  Mean flowtime = 36.2050
# tote =    139;  Entrytime =  10853.8446;  Column = 14;  Mean throughput =0.012780  Mean flowtime = 36.1052
# tote =    168;  Entrytime =  13027.6458;  Column = 28;  Mean throughput =0.012866  Mean flowtime = 34.7444
# tote =    169;  Entrytime =  13067.3448;  Column = 12;  Mean throughput =0.012921  Mean flowtime = 34.6078
# tote =    170;  Entrytime =  13088.1424;  Column = 50;  Mean throughput =0.012970  Mean flowtime = 34.5160
# tote =    171;  Entrytime =  13133.7688;  Column = 24;  Mean throughput =0.012980  Mean flowtime = 34.5500
# tote =    172;  Entrytime =  13173.9894;  Column = 30;  Mean throughput =0.013019  Mean flowtime = 34.5649
# tote =    173;  Entrytime =  13179.3064;  Column = 28;  Mean throughput =0.013053  Mean flowtime = 34.7974
# tote =    174;  Entrytime =  13268.8042;  Column = 52;  Mean throughput =0.013068  Mean flowtime = 34.8599
# tote =    175;  Entrytime =  13285.2810;  Column = 12;  Mean throughput =0.013120  Mean flowtime = 34.9665
# tote =    176;  Entrytime =  13319.2613;  Column = 32;  Mean throughput =0.013182  Mean flowtime = 34.9490
# tote =    177;  Entrytime =  13404.3859;  Column = 39;  Mean throughput =0.013182  Mean flowtime = 34.8815
# tote =    178;  Entrytime =  13424.2950;  Column = 41;  Mean throughput =0.013242  Mean flowtime = 34.7834
# tote =    179;  Entrytime =  13438.1872;  Column = 38;  Mean throughput =0.013287  Mean flowtime = 34.7745
# tote =    180;  Entrytime =  13454.6570;  Column =  4;  Mean throughput =0.013344  Mean flowtime = 34.7724
# tote =    181;  Entrytime =  13624.5861;  Column =  0;  Mean throughput =0.013265  Mean flowtime = 34.6927
# tote =    182;  Entrytime =  13701.6081;  Column = 53;  Mean throughput =0.013253  Mean flowtime = 34.6724
# tote =    183;  Entrytime =  13725.4340;  Column = 12;  Mean throughput =0.013306  Mean flowtime = 34.6369
# tote =    184;  Entrytime =  13754.9030;  Column = 36;  Mean throughput =0.013337  Mean flowtime = 34.6715
# tote =    185;  Entrytime =  13771.3981;  Column = 18;  Mean throughput =0.013399  Mean flowtime = 34.6754
# tote =    186;  Entrytime =  13829.3274;  Column = 23;  Mean throughput =0.013410  Mean flowtime = 34.7094
# tote =    187;  Entrytime =  13829.3473;  Column = 30;  Mean throughput =0.013458  Mean flowtime = 34.8731
# tote =    188;  Entrytime =  13940.8117;  Column = 39;  Mean throughput =0.013452  Mean flowtime = 34.8702
# tote =    189;  Entrytime =  14009.3699;  Column =  2;  Mean throughput =0.013454  Mean flowtime = 34.8885
# tote =    190;  Entrytime =  14011.4516;  Column = 13;  Mean throughput =0.013487  Mean flowtime = 35.1045
# tote =    191;  Entrytime =  14049.2101;  Column =  0;  Mean throughput =0.013527  Mean flowtime = 35.2898
# tote =    192;  Entrytime =  14099.1671;  Column = 24;  Mean throughput =0.013566  Mean flowtime = 35.3883
# tote =    193;  Entrytime =  14113.4852;  Column = 49;  Mean throughput =0.013623  Mean flowtime = 35.4824
# tote =    194;  Entrytime =  14129.5164;  Column = 45;  Mean throughput =0.013683  Mean flowtime = 35.5491
# tote =    195;  Entrytime =  14305.8924;  Column = 39;  Mean throughput =0.013592  Mean flowtime = 35.5770
# tote =    280;  Entrytime =  20622.1523;  Column = 35;  Mean throughput =0.013567  Mean flowtime = 36.1665
# tote =    281;  Entrytime =  20632.0016;  Column = 22;  Mean throughput =0.013609  Mean flowtime = 36.0973
# tote =    282;  Entrytime =  20637.7741;  Column = 12;  Mean throughput =0.013644  Mean flowtime = 36.0778
# tote =    283;  Entrytime =  20663.1557;  Column = 21;  Mean throughput =0.013680  Mean flowtime = 36.0336
# tote =    284;  Entrytime =  20772.1658;  Column = 27;  Mean throughput =0.013648  Mean flowtime = 36.0370
# tote =    285;  Entrytime =  20844.4600;  Column = 50;  Mean throughput =0.013660  Mean flowtime = 35.9796
# tote =    286;  Entrytime =  21095.0624;  Column = 47;  Mean throughput =0.013531  Mean flowtime = 36.0018
# tote =    287;  Entrytime =  21182.6762;  Column = 33;  Mean throughput =0.013522  Mean flowtime = 36.0238
# tote =    288;  Entrytime =  21216.2461;  Column = 19;  Mean throughput =0.013556  Mean flowtime = 35.9998
# tote =    289;  Entrytime =  21331.4885;  Column = 53;  Mean throughput =0.013535  Mean flowtime = 35.9479
# tote =    290;  Entrytime =  21393.8400;  Column = 48;  Mean throughput =0.013544  Mean flowtime = 35.8848
# tote =    291;  Entrytime =  21451.7798;  Column = 41;  Mean throughput =0.013553  Mean flowtime = 35.8291
# tote =    292;  Entrytime =  21518.7609;  Column = 24;  Mean throughput =0.013549  Mean flowtime = 35.8194
# tote =    293;  Entrytime =  21623.7574;  Column = 11;  Mean throughput =0.013522  Mean flowtime = 35.8485
# tote =    294;  Entrytime =  21734.8752;  Column = 13;  Mean throughput =0.013499  Mean flowtime = 35.8773
# tote =    295;  Entrytime =  21753.4211;  Column = 24;  Mean throughput =0.013535  Mean flowtime = 35.8962
# tote =    296;  Entrytime =  21788.0339;  Column =  0;  Mean throughput =0.013554  Mean flowtime = 35.9479
# tote =    297;  Entrytime =  21839.4138;  Column = 51;  Mean throughput =0.013575  Mean flowtime = 35.9581
# tote =    298;  Entrytime =  21865.6066;  Column = 11;  Mean throughput =0.013606  Mean flowtime = 35.9576
# tote =    299;  Entrytime =  21880.7729;  Column = 21;  Mean throughput =0.013625  Mean flowtime = 36.0547
# tote =    300;  Entrytime =  21950.4043;  Column = 35;  Mean throughput =0.013651  Mean flowtime = 36.0200
# tote =    301;  Entrytime =  21968.1301;  Column = 50;  Mean throughput =0.013689  Mean flowtime = 35.9699
# tote =    302;  Entrytime =  22022.7892;  Column = 42;  Mean throughput =0.013695  Mean flowtime = 35.9447
# tote =    303;  Entrytime =  22170.1280;  Column = 46;  Mean throughput =0.013645  Mean flowtime = 35.9459
# tote =    304;  Entrytime =  22195.3022;  Column = 49;  Mean throughput =0.013665  Mean flowtime = 35.9949
# tote =    305;  Entrytime =  22203.8123;  Column = 20;  Mean throughput =0.013699  Mean flowtime = 36.0735
# tote =    306;  Entrytime =  22212.2815;  Column =  4;  Mean throughput =0.013729  Mean flowtime = 36.2057
# tote =    307;  Entrytime =  22234.9720;  Column = 37;  Mean throughput =0.013760  Mean flowtime = 36.3380
# tote =    308;  Entrytime =  22300.0663;  Column = 46;  Mean throughput =0.013798  Mean flowtime = 36.2906
# tote =    309;  Entrytime =  22344.2284;  Column = 27;  Mean throughput =0.013803  Mean flowtime = 36.3123
# tote =    310;  Entrytime =  22393.5647;  Column = 14;  Mean throughput =0.013832  Mean flowtime = 36.2521
# tote =    311;  Entrytime =  22414.1307;  Column =  5;  Mean throughput =0.013866  Mean flowtime = 36.1838
# tote =    312;  Entrytime =  22507.8662;  Column = 11;  Mean throughput =0.013850  Mean flowtime = 36.1287
# tote =    313;  Entrytime =  22751.4007;  Column = 37;  Mean throughput =0.013751  Mean flowtime = 36.0452
# tote =    314;  Entrytime =  22776.1290;  Column = 40;  Mean throughput =0.013771  Mean flowtime = 36.0122
# tote =    315;  Entrytime =  23009.2532;  Column = 53;  Mean throughput =0.013667  Mean flowtime = 36.0196
# tote =    316;  Entrytime =  23063.1581;  Column = 17;  Mean throughput =0.013678  Mean flowtime = 36.0290
# tote =    317;  Entrytime =  23117.8141;  Column = 20;  Mean throughput =0.013702  Mean flowtime = 35.9711
# tote =    318;  Entrytime =  23173.9877;  Column =  9;  Mean throughput =0.013706  Mean flowtime = 35.9449
# tote =    319;  Entrytime =  23185.5968;  Column = 36;  Mean throughput =0.013743  Mean flowtime = 35.9168
# tote =    320;  Entrytime =  23195.1325;  Column = 36;  Mean throughput =0.013777  Mean flowtime = 35.9038
# tote =    321;  Entrytime =  23247.4855;  Column = 48;  Mean throughput =0.013788  Mean flowtime = 35.8989
# tote =    322;  Entrytime =  23255.3363;  Column = 32;  Mean throughput =0.013804  Mean flowtime = 36.0073
# tote =    323;  Entrytime =  23259.6082;  Column = 53;  Mean throughput =0.013824  Mean flowtime = 36.2205
# tote =    324;  Entrytime =  23268.1592;  Column = 13;  Mean throughput =0.013857  Mean flowtime = 36.4585
# tote =    325;  Entrytime =  23501.1114;  Column = 44;  Mean throughput =0.013812  Mean flowtime = 36.4376
# tote =    326;  Entrytime =  23609.0759;  Column = 46;  Mean throughput =0.013797  Mean flowtime = 36.3841
# tote =    327;  Entrytime =  23731.3285;  Column =  5;  Mean throughput =0.013755  Mean flowtime = 36.3982
# tote =    328;  Entrytime =  23732.1218;  Column = 38;  Mean throughput =0.013789  Mean flowtime = 36.4556
# tote =    329;  Entrytime =  23769.1819;  Column =  8;  Mean throughput =0.013819  Mean flowtime = 36.4597
# tote =    330;  Entrytime =  23899.5219;  Column = 19;  Mean throughput =0.013802  Mean flowtime = 36.3795
# tote =    331;  Entrytime =  23942.4672;  Column = 41;  Mean throughput =0.013810  Mean flowtime = 36.3472
# tote =    332;  Entrytime =  24009.8114;  Column =  6;  Mean throughput =0.013819  Mean flowtime = 36.2829
# tote =    333;  Entrytime =  24027.8662;  Column = 17;  Mean throughput =0.013836  Mean flowtime = 36.2910
# tote =    334;  Entrytime =  24041.3913;  Column = 20;  Mean throughput =0.013853  Mean flowtime = 36.3874
# tote =    335;  Entrytime =  24047.4049;  Column = 30;  Mean throughput =0.013875  Mean flowtime = 36.5677
# tote =    364;  Entrytime =  25915.8647;  Column = 34;  Mean throughput =0.014029  Mean flowtime = 36.4807
# tote =    365;  Entrytime =  25946.8162;  Column = 45;  Mean throughput =0.014051  Mean flowtime = 36.4622
# tote =    366;  Entrytime =  26116.4242;  Column =  1;  Mean throughput =0.013997  Mean flowtime = 36.4509
# tote =    367;  Entrytime =  26159.0606;  Column =  0;  Mean throughput =0.014016  Mean flowtime = 36.4197
# tote =    368;  Entrytime =  26184.0741;  Column = 13;  Mean throughput =0.014041  Mean flowtime = 36.3869
# tote =    369;  Entrytime =  26306.5219;  Column = 39;  Mean throughput =0.014006  Mean flowtime = 36.3958
# tote =    370;  Entrytime =  26405.2695;  Column = 41;  Mean throughput =0.013995  Mean flowtime = 36.3848
# tote =    371;  Entrytime =  26417.6020;  Column = 17;  Mean throughput =0.014024  Mean flowtime = 36.3882
# tote =    372;  Entrytime =  26568.2891;  Column = 19;  Mean throughput =0.013978  Mean flowtime = 36.4132
# tote =    373;  Entrytime =  26606.2715;  Column = 51;  Mean throughput =0.014000  Mean flowtime = 36.4139
# tote =    374;  Entrytime =  26625.4916;  Column = 13;  Mean throughput =0.014024  Mean flowtime = 36.4319
# tote =    375;  Entrytime =  26854.0150;  Column = 44;  Mean throughput =0.013956  Mean flowtime = 36.3783
# tote =    376;  Entrytime =  26863.9094;  Column =  1;  Mean throughput =0.013976  Mean flowtime = 36.3882
# tote =    377;  Entrytime =  27061.9538;  Column = 46;  Mean throughput =0.013926  Mean flowtime = 36.3182
# tote =    378;  Entrytime =  27119.1949;  Column = 10;  Mean throughput =0.013921  Mean flowtime = 36.3112
# tote =    379;  Entrytime =  27147.4241;  Column = 28;  Mean throughput =0.013941  Mean flowtime = 36.3150
# tote =    380;  Entrytime =  27177.2174;  Column = 28;  Mean throughput =0.013957  Mean flowtime = 36.3484
# tote =    381;  Entrytime =  27351.3508;  Column = 27;  Mean throughput =0.013910  Mean flowtime = 36.3571
# tote =    382;  Entrytime =  27419.8281;  Column = 46;  Mean throughput =0.013916  Mean flowtime = 36.3430
# tote =    383;  Entrytime =  27449.7441;  Column = 18;  Mean throughput =0.013939  Mean flowtime = 36.3180
# tote =    384;  Entrytime =  27469.6621;  Column = 24;  Mean throughput =0.013969  Mean flowtime = 36.2751
# tote =    385;  Entrytime =  27475.5590;  Column = 38;  Mean throughput =0.013986  Mean flowtime = 36.3166
# tote =    386;  Entrytime =  27540.7294;  Column = 41;  Mean throughput =0.014004  Mean flowtime = 36.2838
# tote =    387;  Entrytime =  27599.2220;  Column = 24;  Mean throughput =0.014009  Mean flowtime = 36.2564
# tote =    388;  Entrytime =  27603.5829;  Column = 39;  Mean throughput =0.014035  Mean flowtime = 36.2720
# tote =    389;  Entrytime =  27626.9836;  Column = 54;  Mean throughput =0.014057  Mean flowtime = 36.2968
# tote =    390;  Entrytime =  27661.1789;  Column = 11;  Mean throughput =0.014077  Mean flowtime = 36.3132
# tote =    391;  Entrytime =  27759.4994;  Column = 13;  Mean throughput =0.014079  Mean flowtime = 36.2519
# tote =    420;  Entrytime =  29716.4026;  Column = 43;  Mean throughput =0.014123  Mean flowtime = 36.0282
# tote =    421;  Entrytime =  29780.5476;  Column = 28;  Mean throughput =0.014123  Mean flowtime = 36.0131
# tote =    422;  Entrytime =  29790.4866;  Column = 47;  Mean throughput =0.014142  Mean flowtime = 36.0432
# tote =    423;  Entrytime =  29815.2195;  Column = 54;  Mean throughput =0.014163  Mean flowtime = 36.0802
# tote =    424;  Entrytime =  29912.9400;  Column =  9;  Mean throughput =0.014159  Mean flowtime = 36.0698
# tote =    425;  Entrytime =  29948.0285;  Column =  8;  Mean throughput =0.014173  Mean flowtime = 36.0767
# tote =    426;  Entrytime =  29965.2940;  Column = 32;  Mean throughput =0.014197  Mean flowtime = 36.0907
# tote =    427;  Entrytime =  30094.1147;  Column = 41;  Mean throughput =0.014184  Mean flowtime = 36.0296
# tote =    428;  Entrytime =  30315.2720;  Column = 21;  Mean throughput =0.014113  Mean flowtime = 35.9743
# tote =    429;  Entrytime =  30368.4926;  Column = 11;  Mean throughput =0.014120  Mean flowtime = 35.9254
# tote =    430;  Entrytime =  30369.5964;  Column = 29;  Mean throughput =0.014143  Mean flowtime = 35.9199
# tote =    431;  Entrytime =  30377.8885;  Column = 40;  Mean throughput =0.014163  Mean flowtime = 35.9609
# tote =    432;  Entrytime =  30448.0617;  Column = 42;  Mean throughput =0.014167  Mean flowtime = 35.9803
# tote =    433;  Entrytime =  30560.6444;  Column = 48;  Mean throughput =0.014156  Mean flowtime = 35.9595
# tote =    434;  Entrytime =  30570.9027;  Column = 23;  Mean throughput =0.014183  Mean flowtime = 35.9421
# tote =    435;  Entrytime =  30630.3171;  Column = 42;  Mean throughput =0.014186  Mean flowtime = 35.9369
# tote =    436;  Entrytime =  30684.6463;  Column = 34;  Mean throughput =0.014193  Mean flowtime = 35.9347
# tote =    437;  Entrytime =  30695.5058;  Column =  7;  Mean throughput =0.014221  Mean flowtime = 35.9306
# tote =    438;  Entrytime =  30716.7328;  Column = 51;  Mean throughput =0.014245  Mean flowtime = 35.9215
# tote =    439;  Entrytime =  30772.1183;  Column = 11;  Mean throughput =0.014247  Mean flowtime = 35.9361
# tote =    440;  Entrytime =  30909.0631;  Column = 42;  Mean throughput =0.014227  Mean flowtime = 35.8976
# tote =    441;  Entrytime =  31000.1535;  Column = 15;  Mean throughput =0.014208  Mean flowtime = 35.9016
# tote =    442;  Entrytime =  31003.2502;  Column = 42;  Mean throughput =0.014230  Mean flowtime = 35.9521
# tote =    443;  Entrytime =  31118.9596;  Column = 50;  Mean throughput =0.014229  Mean flowtime = 35.9018
# tote =    444;  Entrytime =  31223.6668;  Column = 34;  Mean throughput =0.014210  Mean flowtime = 35.8728
# tote =    445;  Entrytime =  31236.5680;  Column = 12;  Mean throughput =0.014229  Mean flowtime = 35.8770
# tote =    446;  Entrytime =  31253.6830;  Column = 19;  Mean throughput =0.014245  Mean flowtime = 35.9213
# tote =    447;  Entrytime =  31371.5778;  Column = 20;  Mean throughput =0.014235  Mean flowtime = 35.9074
# tote =    990;  Entrytime =  67849.0214;  Column = 23;  Mean throughput =0.014581  Mean flowtime = 37.8858
# tote =    991;  Entrytime =  67927.7120;  Column = 20;  Mean throughput =0.014585  Mean flowtime = 37.8661
# tote =    992;  Entrytime =  68120.1587;  Column =  5;  Mean throughput =0.014561  Mean flowtime = 37.8368
# tote =    993;  Entrytime =  68155.6914;  Column =  5;  Mean throughput =0.014563  Mean flowtime = 37.8313
# tote =    994;  Entrytime =  68166.7345;  Column = 35;  Mean throughput =0.014572  Mean flowtime = 37.8398
# tote =    995;  Entrytime =  68197.6591;  Column = 17;  Mean throughput =0.014583  Mean flowtime = 37.8363
# tote =    996;  Entrytime =  68211.4888;  Column = 50;  Mean throughput =0.014588  Mean flowtime = 37.8641
# tote =    997;  Entrytime =  68212.0831;  Column =  1;  Mean throughput =0.014594  Mean flowtime = 37.9297
# tote =    998;  Entrytime =  68351.1989;  Column = 14;  Mean throughput =0.014596  Mean flowtime = 37.9148
# tote =    999;  Entrytime =  68399.6160;  Column = 44;  Mean throughput =0.014596  Mean flowtime = 37.9199
# tote =   1000;  Entrytime =  68432.7012;  Column = 36;  Mean throughput =0.014605  Mean flowtime = 37.9168
# simulation has ended

# %% [markdown]
# f.  Run your simulation at least 10 times. What is the range of outcomes for the throughput? Determine (roughly, by trial and error) the number of orders required to get good estimates for the flow time (first three **non-zero** digits are correct).

# %% [markdown]
# Answer: ...

# %% [markdown]
# ## 6.5 Exercise 5: Lift as two stage machine (5 points)
# In the previous exercises we focussed on modeling a tier. In exercises 5-7 we focus on modeling the Buffer and Lift, starting with the Lift. We model the Lift as a machine, which repeatedly does the following: request a destination tier, move to the desired tier, receive a tote (first delay for $ll$, then communicate), move to the ground floor, deliver the tote (first delay for $ll$, then communicate). In this exercise we assume that moving to the desired tier takes 23.0 seconds, receiving the tote takes 2.0 seconds, moving to the ground floor again takes 23.0 seconds, and delivering the tote also takes 2.0 seconds. Note that, in this case, this implies that the tote should leave the Generator and enter the Lift 25.0 seconds after the Lift has received the destination tier. All of these times are assumed to be deterministic.
#
# a. Assume that after 1.0 second the first tote arrives at the generator. Subsequently a tote arrives respectively 10.0, 100.0, and 100.0 seconds after the previous tote has been sent to the Lift. Make a lot-time-diagram indicating how long a newly generated job spends in the Generator, and spends in the Lift. We have provided the function `draw_lot_time_diagram(locations, lots)`, which can be used to draw the lot-time-diagram. Below, lot0 has been given as an example. Use the simulation code below 6.5.b to confirm that your lot-time-diagram is correct.
#
# Answer:

# %%
# =================================
# Draw the lot-time-diagram
# =================================

# Set the locations
locations = ('G', 'L')

# For each lot, give the entry and exit times at respectively the generator G and lift L.
# The first lot is given as an example.
lot0 = { 'G':[  0,    26],   'L':[  26,   51] };
lot1 = { ... };
lot2 = { ... };
lot3 = { ... };

# Add all lots together
lots = [lot0, lot1, lot2, lot3];

# Draw the lot-time diagram
draw_lot_time_diagram(locations, lots)

# %% [markdown]
# b. 	Study the Lift in the simulation code below. Can you describe (in one sentence) what each of its channels, events, and entities represent?

# %% [markdown]
# Answer:
#
#     channel1:
#     channel2:
#     channel3:
#
#     event1:
#     event2:
#     event3:
#     event4:
#     event5:
#
#     entity1:
#     entity2:

# %%
# =================================
# Tote definition
# =================================
@dataclass
class Tote:
    entrytime: float = 0
    tier: int = 0

# =================================
# Generator
# =================================
@process
def Generator(env, c1, c2):
    delays=[1.0, 10.0, 100.0, 100.0]
    while len(delays)>0:
        yield env.timeout(delays[0])
        delays = delays[1:]
        tier = 1
        yield env.execute(c1.send(tier))
        print(f"Generator: Informed Lift to go to tier {tier} at time {env.now:3.1f}");
        x = Tote(entrytime = env.now, tier = tier)
        yield env.execute(c2.send(x))
        print(f"Generator: Tote has completely left the Generator and entered"
              f"the Lift at time {env.now:3.1f}")
    yield env.timeout(100.0)


# =================================
# Lift
# =================================
@process
def Lift(env, channel1, channel2, channel3, ll):
    while True:
        
        event1 = channel1.receive()
        entity1 = yield env.execute(event1)
        
        event2 = env.timeout(23.0+ll)
        yield event2
        
        event3 = channel2.receive()
        entity2 = yield env.execute(event3)
        
        event4 = env.timeout(23.0+ll)
        yield event4
        
        event5 = channel3.send(entity2)
        yield env.execute(event5)
    
# =================================
# Exit 
# =================================
@process
def Exit(env, c_in):
    while True:
        x = yield env.execute(c_in.receive())
        print(f"Exit: Tote has completely left the Lift and has been received "
              f"by the Exit at time {env.now:3.1f}");

# =================================
# Model
# =================================
def model():
    # Variables
    ll = 2.0  # time to load/unload the lift
    
    env = Environment()
    a = Channel(env)
    b = Channel(env)
    c = Channel(env)
    G = Generator(env, a, b)
    L = Lift(env, a, b, c, ll)
    E = Exit(env, c)
    env.run()
    print ("simulation has ended")

# =================================
# Main
# =================================
model()

# %% [markdown]
# ## 6.6 Exercise 6: Buffer with multiple tiers (10 points)
# Every tier has a buffer location of finite capacity $bc$. In this exercise, these parallel finite buffer locations are modelled as one Buffer model.

# %% [markdown]
# a. Study the simulation code below. Can you describe (concisely) why the events of the buffer are modelled the way they are:
#
#     events1: ...
#     event2: ...
#     event3: ...
#
# and can you explain what happens when an event occurs:
#
#     events1: ...
#     event2: ...
#     event3: ...

# %% [markdown]
# Answer: ...

# %%
# =================================
# Generator
# =================================
@process
def Generator(env, c_out, tier):
    delays=[1.0*tier, 10.0, 100.0, 100.0]
    while len(delays)>0:
        yield env.timeout(delays[0])
        delays = delays[1:]
        x = Tote(entrytime = env.now, tier = tier)
        yield env.execute(c_out.send(x))
        print(f"Generator {tier:d}: Sending tote to Buffer completed at "
              f"time {env.now:3.1f}")
    yield env.timeout(100.0)
    
# =================================
# Buffer
# =================================
@process
def Buffer(env, channels1, channel2, channel3, bc, Levels):
    xs = []
    n = [0] * Levels
    lift_called = False
    while True:
        # Define events
        events1 = [channels1[tier].receive() if n[tier] < bc else None for tier in range(Levels)]
        if not lift_called:
            event3 = None
            if len(xs) > 0:
                x_sending = xs[0]
                event2 = channel2.send(x_sending.tier)
            else:
                event2 = None
        else:
            event2 = None
            event3 = channel3.send(x_sending)
        
        # Execute one of the events
        events = receiving_events  + [event2] + [event3]
        yield env.select(*events)    
        
        # Check which event is executed
        for tier in range(Levels):
            if selected(receiving_events[tier]):
                x_received = receiving_events[tier].entity
                xs = xs + [x_received]
                n[tier] = n[tier] + 1
            
        if selected(event2):
            lift_called = True
           
        if selected(event3):
            xs = xs[1:]
            n[x_sending.tier] = n[x_sending.tier] - 1
            lift_called = False
            
            
# =================================
# Model
# =================================
def model():
    # Variables
    ll = 2.0  # time to load/unload the lift
    bc = 1    # buffer capacity
    Levels = 2 # the number of tiers
    
    env = Environment()
    a = [Channel(env) for tier in range(Levels)]
    b = Channel(env)
    c = Channel(env)
    d = Channel(env)
    Gs = [Generator(env, a[tier], tier) for tier in range(Levels)] 
    B = Buffer(env, a, b, c, bc, Levels)
    L = Lift(env, b, c, d, ll)
    E = Exit(env, d)
    env.run(until=10000000)
    print ("simulation has ended")

# =================================
# Main
# =================================
model()

# %% [markdown]
# b. Consider two tiers ($Levels = 2$), and assume that for tier $i \in \{0, Levels - 1\}$ the first tote arrives after $i$ seconds (for two tiers: after 0.0 for tier 0 and after 1.0 for tier 1). Subsequently a tote arrives respectively 10.0, 100.0, and 100.0 seconds after the completion of sending its predecessor to the buffer. Make a lot-time-diagram indicating how long a newly generated job spends in which Generator (G0 or G1), in the Buffer, and spends in the Lift.
#
# Answer:

# %%
# =================================
# Draw the lot-time-diagram
# =================================

# Set the locations
locations = ('G0', 'G1', 'B', 'L')

# For each lot, give the entry and exit times at generators G0 and G1, the buffer B, and lift L.
lot0 = { 'G0':[   0,     0], 'B':[... , ... ],   'L':[  ... ,   ... ] };
lot1 = { 'G1':[   1,     1], 'B':[... , ... ],   'L':[  ... ,   ... ] };
lot2 = { ... };
lot3 = { ... };
lot4 = { ... };
lot5 = { ... };
lot6 = { ... };
lot7 = { ... };

# Add all lots together
lots = [lot0, lot1, lot2, lot3, lot4, lot5, lot6, lot7];

# Draw the lot-time diagram
draw_lot_time_diagram(locations, lots)

# %% [markdown]
# c. Suppose that we want the system to be able to handle priority orders, can you modify the Buffer model to make the lift pick up totes with higher priority first? The generator generates totes with a `tote.priority` property, for which priority 1 is high priority, and priority 2 is low priority. Only the Buffer model needs to be modified, the Tote, Generator and Exit models have already been modified. Give the model of the buffer, and the output log when you run it to show that the buffer is modelled correctly.
#
# **Note: in the exercise 6.7 onwards, the Buffer without priorities will be used.**

# %%
# =================================
# Tote definition
# =================================
@dataclass
class Tote:
    entrytime: float = 0
    tier: int = 0
    priority: int = 0
        
# =================================
# Generator
# =================================
@process
def Generator(env, c_out, tier):
    delays=[1.0*tier, 1.0, 1.0, 1.0]
    priorities=[2, tier+1, tier+1, 1]
    while len(delays)>0:
        yield env.timeout(delays[0])
        delays = delays[1:]
        priority = priorities[0]
        priorities = priorities[1:]
        x = Tote(entrytime = env.now, tier = tier, priority = priority)
        yield env.execute(c_out.send(x))
        print(f"Generator {tier:d}: Sending tote with priotity {priority} to Buffer completed at "
              f"time {env.now:3.1f}")
    yield env.timeout(100.0)
    
# =================================
# Buffer
# =================================
@process
def Buffer(env, channels1, channel2, channel3, bc, Levels):
    xs = # ... 
    n = [0] * Levels
    lift_called = False
    while True:
        # Define events
        events1 = [channels1[tier].receive() if n[tier] < bc else None for tier in range(Levels)]
        if not lift_called:
            event3 = None
            # ...
            # ...
            # ...
            # ...
            # ...
        else:
            event2 = None
            event3 = channel3.send(x_sending)
        
        # Execute one of the events
        events = receiving_events  + [event2] + [event3]
        yield env.select(*events)    
        
        # Check which event is executed
        for tier in range(Levels):
            if selected(receiving_events[tier]):
                x_received = receiving_events[tier].entity
                # ...
                # ...
                n[tier] = n[tier] + 1
            
        if selected(event2):
            lift_called = True
           
        if selected(event3):
            # ...
            # ...
            n[x_sending.tier] = n[x_sending.tier] - 1
            lift_called = False

# =================================
# Exit 
# =================================
@process
def Exit(env, c_in):
    while True:
        x = yield env.execute(c_in.receive())
        print(f"Exit: Tote with priority {x.priority} has completely left the Lift and has been received "
              f"by the Exit at time {env.now:3.1f}");            
            
# =================================
# Model
# =================================
def model():
    # Variables
    ll = 2.0  # time to load/unload the lift
    bc = 1    # buffer capacity
    Levels = 2 # the number of tiers
    
    env = Environment()
    a = [Channel(env) for tier in range(Levels)]
    b = Channel(env)
    c = Channel(env)
    d = Channel(env)
    Gs = [Generator(env, a[tier], tier) for tier in range(Levels)] 
    B = Buffer(env, a, b, c, bc, Levels)
    L = Lift(env, b, c, d, ll)
    E = Exit(env, d)
    env.run(until=10000000)
    print ("simulation has ended")

# =================================
# Main
# =================================
model()

# %% [markdown]
# ## 6.7 Exercise 7: Lift accurately modelled (5 points)
#
# Assume that the Lift starts from the ground floor. If it has to go to tier $i \in \{0, Levels - 1\}$, it needs to travel a
# distance $dl \cdot (i + 1)$, pick up the tote, travel back, and deliver the tote at the ground floor. For traveling the required distance, the vehicle first goes with a constant acceleration $al$ *m/s$^2$* until it reaches its maximum velocity $vmaxl$, then it moves with this velocity and decelerates with a constant deceleration $al$ to approach its destination tier. If the tier is located too close to the ground floor, it is possible that the Lift will not reach its maximum speed. Loading and unloading a tote both take $ll$ seconds,

# %% [markdown]
# a. The time the lift is moving can be calculated similarly to how it was done for the vehicle in Exercise 4. Note that it takes the Lift half the time to move to pick the tote up, and then half the time to move back to drop the tote off. Using this information, determine (analytically) the time $t_{total}(i)$ it takes the Lift to pick up and drop off the item in terms of $ i $, $ dl $, $ al $, $ ll $, and $ vmaxl $.

# %% [markdown]
# Answer: ...
#
# $
# t_{total}(i) =
#     \begin{cases}
#       ... \ , & \text{for} \ ... \leq \ ... \ , \\
#       ... \ , & \text{for} \ ... >    \ ... \ .
#     \end{cases}
# $

# %% [markdown]
# b. Consider two tiers ($Levels = 2$), and assume that for tier $i \in \{0, Levels - 1\}$ the first tote arrives after $i$ seconds (for two tiers: after 0.0 for tier 0 and after 1.0 for tier 1). Subsequently a tote arrives respectively 10.0, 100.0, and 100.0 seconds after the completion of sending its predecessor to the buffer. Make a lot-time-diagram indicating how long a newly generated job spends in which Generator, in the Buffer, and spends in the Lift.

# %%
# =================================
# Draw the lot-time-diagram
# =================================

# Set the locations
locations = ('G0', 'G1', 'B', 'L')

# For each lot, give the entry and exit times at generators G0 and G1, the buffer B, and lift L.
lot0 = { ... };
lot1 = { ... };
lot2 = { ... };
lot3 = { ... };
lot4 = { ... };
lot5 = { ... };
lot6 = { ... };
lot7 = { ... };

# Add all lots together
lots = [lot0, lot1, lot2, lot3, lot4, lot5, lot6, lot7];

# Draw the lot-time diagram
draw_lot_time_diagram(locations, lots)

# %% [markdown]
# c. Complete the Lift in the simulation code in the template below, and confirm that your simulations produce the correct results, i.e., in correspondence with your lot-time-diagram.

# %%
# =================================
# Tote definition
# =================================
@dataclass
class Tote:
    entrytime: float = 0
    tier: int = 0

# =================================
# Lift
# =================================
@process
def Lift(env, channel1, channel2, channel3, ll, dl, vmaxl, al):
    while True:
        
        event1 = channel1.receive()
        entity1 = yield env.execute(event1)
        
        t_total = ...
        
        event2 = env.timeout(t_total/2)
        yield event2
        
        event3 = channel2.receive()
        entity2 = yield env.execute(event3)
        
        event4 = env.timeout(t_total/2)
        yield event4
        
        event5 = channel3.send(entity2)
        yield env.execute(event5)

# =================================
# Buffer
# =================================
@process
def Buffer(env, channels1, channel2, channel3, bc, Levels):
    xs = []
    n = [0] * Levels
    lift_called = False
    while True:
        # Define events
        events1 = [channels1[tier].receive() if n[tier] < bc else None for tier in range(Levels)]
        if not lift_called:
            event3 = None
            if len(xs) > 0:
                x_sending = xs[0]
                event2 = channel2.send(x_sending.tier)
            else:
                event2 = None
        else:
            event2 = None
            event3 = channel3.send(x_sending)
        
        # Execute one of the events
        events = receiving_events  + [event2] + [event3]
        yield env.select(*events)    
        
        # Check which event is executed
        for tier in range(Levels):
            if selected(receiving_events[tier]):
                x_received = receiving_events[tier].entity
                xs = xs + [x_received]
                n[tier] = n[tier] + 1
            
        if selected(event2):
            lift_called = True
           
        if selected(event3):
            xs = xs[1:]
            n[x_sending.tier] = n[x_sending.tier] - 1
            lift_called = False
        
# =================================
# Model
# =================================
def model():
    # Variables
    ll = 2.0        # time to load/unload the lift
    bc = 1          # buffer capacity
    Levels = 2      # the number of tiers
    dl = 0.8        # unit height clearance
    vmaxl = 5.0     # maximum velocity of lift
    al = 7.0        # acceleration/deceleration of lift
    
    env = Environment()
    a = [Channel(env) for tier in range(Levels)] # a channel for each tier, each sending totes
    b = Channel(env)  # for sending totes
    c = Channel(env)  # for calling the lift
    d = Channel(env)  # for sending totes
    Gs = [Generator(env, a[tier], tier) for tier in range(Levels)] 
    B = Buffer(env, a, b, c, bc, Levels)
    L = Lift(env, b, c, d, ll, dl, vmaxl, al)
    E = Exit(env, d)
    env.run()
    print ("simulation has ended")

    
# =================================
# Main
# =================================
model()

# %% [markdown]
# ## 6.8 Exercise 8: Entire system (10 points)
# In the previous exercises we developed and tested each process individually. Now it is time to combine all processes into one model.

# %% [markdown]
# a. Determine the (total) arrival rate of orders for a system with $Levels$ tiers, where for each tier orders arrive with a mean inter arrival time of $arrive$.

# %% [markdown]
# Answer: ...

# %% [markdown]
# b. Complete the simulation code in the template below by substituting the code for the processes as you derived in Exercises 1, 2, 4, 6, and 7. Note that the type tote has been extended in comparison with Exercise 1, so extra code is required in the Generator process to include the tier. Verify if the throughput in your simulations matches with the start rate you determined. Verify that totes reach the exit from each tier. Also verify that totes are generated from each column.
#
# If you were not able to complete the Vehicle and Lift models, you can use the simplified models from respectively Exercises 3 and 5, with a total processing time $t_{vehicle, total} = 10 + \frac{depth}{3}$ for the vehicle, and a total processing time $t_{lift, total} = 5 + \frac{Level}{5}$. You can do the same for the following exercises.

# %% [markdown]
# Answer: ...

# %%
# =================================
# Tote
# =================================
@dataclass
class Tote:
    entrytime: float = 0.0
    column: int = 0
    tier: int  = 0
        
        
# =================================
# Generator from Exercise 1 (modified to include tier) 
# =================================
@process
def Generator(env, c_out, arrive, depth, tier):
    #.....
    #.....
    while True:
        x = Tote(entrytime = env.now, column = ..., tier = tier)
        yield env.execute(c_out.send(x))
        delay = #.....
        yield env.timeout(delay)

        
# =================================
# Demand Buffer from Exercise 2
# =================================
@process
def Demand_Buffer(env, c_in, c_out):
    xs = [] # list of totes
    #.....

    
# =================================
# Vehicle from Exercise 4
# =================================
@process
def Vehicle(env, c_in, c_out, lv, dv, vmaxv, av):
    #.....

    
# =================================
# Lift from Exercise 7
# =================================
@process
def Lift(env, channel1, channel2, channel3, ll, dl, vmaxl, al):
    #.....

    
# =================================
# Buffer from Exercise 6a
# =================================
@process
def Buffer(env, channels1, channel2, channel3, bc, Levels):
    xs = []
    n = [0] * Levels
    while True:
        events1 = [channels1[tier].receive() if n[tier] < bc else None for tier in range(Levels)]
        event2 = channel2.send(xs[0].tier) if len(xs) > 0 else None
        event3 = channel3.send(xs[0]) if len(xs) > 0 else None
        events = events1 + [event2] + [event3]

        yield env.select(*events)
        
        for tier in range(Levels):
            if selected(events1[tier]):
                x = events1[tier].entity
                xs = xs + [x]
                n[tier] = n[tier] + 1
        
        if selected(event2):
            pass
            
        if selected(event3):
            tier = xs[0].tier 
            xs = xs[1:]
            n[tier] = n[tier] - 1
      
    
# =================================
# Exit
# =================================
@process
def Exit(env, c_in, number_of_orders):
    mphi = 0.0
    for i in range(1, number_of_orders + 1):
        x = yield env.execute(c_in.receive())
        mphi = (i - 1) / i * mphi + (env.now - x.entrytime) / i
        mthi = i/env.now
    return mphi, mthi 


        
# =================================
# GDV Submodel (Generator + DemandBuffer  + Vehicle)
# =================================
def GDV(env, c_out, arrive, depth, tier, lv, dv, vmaxv, av):
    a = Channel(env)
    b = Channel(env)
    G = Generator(env, a, arrive, depth, tier)
    D = Demand_Buffer(env, a, b)
    V = Vehicle(env, b, c_out, lv, dv, vmaxv, av)

    
# =================================
# Model
# =================================
def model(Levels, depth, arrive, bc, number_of_orders):
    # Variables
    lv = 3.0                   # time to load/unload the vehicle
    dv = 0.5                   # unit width clearance
    vmaxv = 1.5                # maximum velocity of the vehicle
    av = 1.0                   # acceleration/deceleration of the vehicle
    ll = 2.0                   # time to load/unload the lift
    dl = 0.8                   # unit height clearance
    vmaxl = 5.0                # maximum velocity of lift
    al = 7.0                   # acceleration/deceleration of lift
    
    env = Environment()
    c = [Channel(env) for tier in range(Levels)] 
    d = Channel(env)  
    e = Channel(env)  
    f = Channel(env)  
    GDVs = [ GDV(env, c[tier], arrive, depth, tier, lv, dv, vmaxv, av)  for tier in range(Levels) ] 
    B = Buffer(env, c, d, e, bc, Levels)
    L = Lift(env, d, e, f, ll, dl, vmaxl, al)
    E = Exit(env, f, number_of_orders)
    env.run(until=E)
    mph, mth = E.value
    return mph, mth


# =================================
# Experiment
# =================================
def experiment():
    Levels = 9                # the number of tiers
    depth  = 55               # the number of columns
    arrive = 70.0             # inter arrival time of requests
    number_of_orders = 10000  # the number of orders to process 
    bc = 1                    # buffer capacity
    
    print(f"--- Experiment {e}: For Levels={Levels}, depth={depth}, arrive={arrive}, bc={bc}, number_of_orders={number_of_orders} --- ")
    mph, mth = model(Levels, depth, arrive, bc, number_of_orders)
    print(f"--- Experiment {e}: Mean throughput = {mth:8.6f}; Mean flowtime = {mph:6.4f} ---")
    
# =================================
# Main
# =================================
experiment()

# %% [markdown]
# c. Run your simulation 30 times, and record for each run the resulting average throughput and average flow time.
# Determine the mean and the standard deviation of both the average throughput and the average flow time for these 30 simulations. Finally, determine a 95% confidence interval for both the average throughput and the average flow time.

# %% [markdown]
# Answer: ...

# %%
def experiment():
     ...
        

experiment()

# %% [markdown]
# ## 6.9 Exercise 9: Effect of buffer capacity (10 points)
# Via computer simulation analyze the impact of the buffer capacity on the throughput and flow time (choose values of $bc$ as 1,2,3,200). For each setting, run your simulations 30 times and determine both mean and standard deviation of the resulting average throughput and average flow time for these 30 simulations, as well as 95% confidence intervals.

# %% [markdown]
# Answer: ...

# %% [markdown]
# ## 6.10 Exercise 10: Looking for the best layout (30 points)
# Via computer simulation consider 6 different scenarios (see the table below) that correspond to different layouts of the
# storage facility with a total capacity of 500 totes with different number of tiers and columns.
#
# | Scenario | 1 | 2 | 3 | 4| 5 | 6 |
# | - | - | - | - | - | - | - |
# | Levels |  2 | 5 | 10 | 20 | 25 | 50 |
# | Depth | 250 | 100 | 50 | 25 | 20 | 10 |
#
# In order to obtain an answer to the questions below: for each scenario, run your simulations 30 times and determine both mean and standard deviation of the resulting average throughput and average flow time for these 30 simulations, as well as 95% confidence intervals.

# %% [markdown]
# a. How can we adjust the model to determine the maximal throughput? For each scenario, determine by means of simulation the maximal throughput. What do you notice about the flowtime?

# %% [markdown]
# Answer: ...

# %% [markdown]
# b. Assume a required throughput of 6 totes per minute. Which of the given scenarios are feasible? Modify your model, and compare the resulting flow time for each feasible scenario.

# %% [markdown]
# Answer: ...

# %% [markdown]
# c. Based on your outcomes, select a layout that seems the best for you. If necessary, introduce other performance indicators and modify the code accordingly. The report on this step should contain an argument to select the best layout.

# %% [markdown]
# Answer: ...

# %% [markdown]
# ## References
# [1] G. Marchet, M. Melanci, S. Perotti and E. Tappia, "Analytical model to estimate performance of autonomous vehicle storage and retrieval systems for product totes", International Journal of Production Research, vol. 50(24), 7134-7148, 2012.
